# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import happybase
import collections
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.9.2
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
pre_days = 2
mem_his_days = 10
num_feature = 17
epoch = 500
train_rate = 0.99
batch_size = 128
table_name = 'certificate'
column_family = 'feature'
stock_code = '002316'

# %%
def change2label(x):
    if x < 0.92:
       return 0
    elif x < 0.94:
       return 1
    elif x < 0.96:
       return 2
    elif x < 0.98:
       return 3
    elif x < 1.:
       return 4
    elif x < 1.2:
       return 5
    elif x < 1.4:
       return 6
    elif x < 1.6:
       return 7
    elif x < 1.8:
       return 8
    return 9

def label2change(label):
    if label == 0:
        return 0.91
    elif label == 1:
        return 0.93
    elif label == 2:
        return 0.95
    elif label == 3:
        return 0.97
    elif label == 4:
        return 0.99
    elif label == 5:
        return 1.1
    elif label == 6:
        return 1.3
    elif label == 7:
        return 1.5
    elif label == 8:
        return 1.7
    return 1.9

# %%
# load features from hbase
connection = happybase.Connection('localhost', 9090, transport='framed', protocol='compact')
connection.open()
table = connection.table(table_name)
rows = table.scan(row_prefix=stock_code.encode('utf-8'))
df = pd.DataFrame()
idx = int(0)
newest_data = '1970-01-01'
for row in rows:
    date = row[0].decode('utf-8').split('_')[-1]
    cells = row[1]
    for column in cells:
        df.at[idx, column.decode('utf-8').split(':')[-1]] = np.float32(cells[column].decode('utf-8'))
    df.at[idx, 'date'] = date
    newest_data = max(date, newest_data)
    
    idx = idx + 1
connection.close()
df.dropna(inplace=True)
df
# Out:
#       macd_dea  macd_diff  macd_ema12  macd_ema26  macd_macd  trade_c  \
# 8       -0.130     -0.836   34.603001   35.439400     -1.412    31.18
# 9       -0.352     -1.241   33.704102   34.944599     -1.776    28.76
# 10      -0.561     -1.397   33.224998   34.622002     -1.672    30.59
# 11      -0.737     -1.439   32.944199   34.383301     -1.405    31.40
# 12      -0.891     -1.508   32.605099   34.113400     -1.234    30.74
# ...        ...        ...         ...         ...        ...      ...
# 2852     0.113      0.165    5.015800    4.851300      0.104     5.54
# 2853     0.129      0.196    5.099500    4.903800      0.133     5.56
# 2854     0.143      0.200    5.135000    4.935400      0.113     5.33
# 2855     0.163      0.243    5.246500    5.003900      0.159     5.86
# 2856     0.195      0.321    5.431700    5.111000      0.252     6.45
#
#           trade_e    trade_h   trade_hs    trade_l    trade_o    trade_v  \
# 8      90117944.0  31.690001  12.060000  30.400000  30.469999    28941.0
# 9     114190072.0  31.080000  16.139999  28.600000  30.889999    38735.0
# 10    155427968.0  31.290001  21.440001  28.690001  28.690001    51455.0
# 11    152094352.0  31.799999  20.629999  29.389999  30.170000    49503.0
# 12     90032200.0  31.389999  12.130000  30.420000  30.500000    29106.0
# ...           ...        ...        ...        ...        ...        ...
# 2852  212349872.0   5.540000  12.510000   5.010000   5.010000   394061.0
# 2853  599063808.0   5.940000  33.700001   5.400000   5.540000  1061622.0
# 2854  313424032.0   5.480000  18.760000   5.200000   5.410000   591018.0
# 2855  271282048.0   5.860000  14.860000   5.230000   5.250000   468242.0
# 2856   70665760.0   6.450000   3.480000   6.450000   6.450000   109559.0
#
#       trade_zd  trade_zde  trade_zf        date      kdj_d       kdj_j  \
# 8         1.53       0.47      4.20  2009-12-21   8.500000    8.500000
# 9        -7.76      -2.42      7.95  2009-12-22   7.680000    2.790000
# 10        6.36       1.83      9.04  2009-12-23   8.030000   10.130000
# 11        2.65       0.81      7.88  2009-12-24   9.880000   20.980000
# 12       -2.10      -0.66      3.09  2009-12-25  12.130000   25.660000
# ...        ...        ...       ...         ...        ...         ...
# 2852      9.92       0.50     10.52  2023-07-14  65.970001   74.309998
# 2853      0.36       0.02      9.75  2023-07-17  66.760002   71.500000
# 2854     -4.14      -0.23      5.04  2023-07-18  65.019997   54.520000
# 2855      9.94       0.53     11.82  2023-07-19  67.360001   81.459999
# 2856     10.07       0.59      0.00  2023-07-20  72.019997  100.040001
#
#           kdj_k
# 8      8.500000
# 9      6.050000
# 10     8.730000
# 11    13.580000
# 12    16.639999
# ...         ...
# 2852  68.750000
# 2853  68.339996
# 2854  61.520000
# 2855  72.059998
# 2856  81.360001
#
# [2849 rows x 19 columns]

# %%
df['PreHigh'] = df['trade_h'].shift(1)
df["Change"] = df['trade_h'] / df['PreHigh']

df = df.dropna()
change = np.array(df['Change']).astype(np.float32)
df['Change'] = df['Change'].apply(change2label)

df = df.drop('trade_h', axis=1)
df = df.drop('PreHigh', axis=1)

date = df['date']
df = df.drop(labels='date', axis=1)

scaler = MinMaxScaler((0, 1))

sca = scaler.fit_transform(df.iloc[:, :-1])
print(scaler.data_max_, scaler.data_min_)
label = np.array(df.iloc[:, -1])
print(sca)
print(label)
print(change)
# Out:
# [2.06299996e+00 2.34999990e+00 3.37041016e+01 3.49445992e+01
#  1.86300004e+00 3.50800018e+01 1.73344512e+09 5.65800018e+01
#  3.36300011e+01 3.50000000e+01 1.66022800e+06 1.01199999e+01
#  2.24000001e+00 1.99500008e+01 9.65899963e+01 1.24339996e+02
#  9.90800018e+01] [-2.39299989e+00 -2.64299989e+00  2.29970002e+00  2.41529989e+00
#  -1.77600002e+00  2.24000001e+00  4.41216000e+05  5.00000007e-02
#   2.21000004e+00  2.22000003e+00  1.53200000e+03 -3.29399986e+01
#  -6.32000017e+00  0.00000000e+00  4.46000004e+00 -2.51299992e+01
#   1.70000005e+00]
# [[0.4580341  0.28079309 1.         ... 0.03495061 0.18679334 0.04467036]
#  [0.41113105 0.24954937 0.98474408 ... 0.03874959 0.23590018 0.07219141]
#  [0.37163374 0.24113758 0.97580266 ... 0.05882992 0.30849    0.1219963 ]
#  ...
#  [0.56912028 0.56939716 0.09028353 ... 0.65733202 0.53288287 0.61429451]
#  [0.57360861 0.57800921 0.09383398 ... 0.68273096 0.7131197  0.72253025]
#  [0.58078994 0.59363109 0.09973125 ... 0.73331162 0.8374256  0.81803244]]
# [4 5 5 ... 1 5 5]
# [0.980751  1.0067568 1.0162991 ... 0.9225589 1.0693431 1.1006825]
# /var/folders/b1/0fd1b6hs7lz0fm_mh346lybm0000gn/T/ipykernel_80201/3599398066.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Change'] = df['Change'].apply(change2label)

# %%
deq = collections.deque()

x = list()
for row in sca:
    deq.append(list(row))
    if len(deq) > mem_his_days:
        deq.popleft()
    if len(deq) == mem_his_days:
        x.append(np.array(deq).reshape(-1, 1))
predict_x = x[-pre_days:]
x = x[:-pre_days]
y = label[mem_his_days + pre_days - 1:]
change = change[mem_his_days + pre_days - 1:]

x, y = np.array(x).reshape(-1, num_feature * mem_his_days, 1), np.array(y)
print(x.shape)
print(y.shape)
# Out:
# (2837, 170, 1)
# (2837,)

# %%
total_num = len(x)
train_num = int(total_num * train_rate)
print(train_num)
# Out:
# 2808

# %%
x_train, y_train, change_train = x[:train_num], y[:train_num], change[:train_num]
x_test, y_test, change_test = x[train_num:], y[train_num:], change[train_num:]

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.shuffle(train_num).batch(batch_size=batch_size).prefetch(tf.data.experimental.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_ds = test_ds.shuffle(total_num - train_num).batch(batch_size=batch_size).prefetch(tf.data.experimental.AUTOTUNE)

sample = next(iter(train_ds))
print('x_train.shape:', sample[0].shape)
print('y_train.shape:', sample[1].shape)
print(change_test)
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# x_train.shape: (128, 170, 1)
# y_train.shape: (128,)
# [0.9912854  1.0021977  0.99561405 1.0726871  0.99589324 0.97938144
#  0.9978947  1.0126584  0.9874999  0.98312235 0.95708156 1.0403587
#  1.0625     0.9776877  1.0311203  1.         0.98792756 1.0285133
#  1.0118812  0.98043054 0.9900199  1.0705645  1.0338982  0.9489982
#  1.0633397  1.0722022  0.9225589  1.0693431  1.1006825 ]
# 2023-07-21 13:32:00.027274: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-21 13:32:00.027422: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
input_shape = sample[0].shape[-2:]
print(input_shape)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv1D(32,num_feature * mem_his_days,input_shape=input_shape,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.MaxPooling1D())
model.add(tf.keras.layers.Conv1D(64,num_feature * mem_his_days,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.MaxPooling1D())
model.add(tf.keras.layers.Conv1D(64,num_feature * mem_his_days,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.GlobalAveragePooling1D())
model.add(tf.keras.layers.Dense(64))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dense(10,activation='softmax'))
model.build(input_shape=[None, num_feature * mem_his_days])

model.summary()
# Out:
# (170, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 170, 32)           5472
#
#  batch_normalization (BatchN  (None, 170, 32)          128
#  ormalization)
#
#  re_lu (ReLU)                (None, 170, 32)           0
#
#  dropout (Dropout)           (None, 170, 32)           0
#
#  max_pooling1d (MaxPooling1D  (None, 85, 32)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 85, 64)            348224
#
#  batch_normalization_1 (Batc  (None, 85, 64)           256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 85, 64)            0
#
#  dropout_1 (Dropout)         (None, 85, 64)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 42, 64)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 42, 64)            696384
#
#  batch_normalization_2 (Batc  (None, 42, 64)           256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 42, 64)            0
#
#  dropout_2 (Dropout)         (None, 42, 64)            0
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                4160
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,055,786
# Trainable params: 1,055,338
# Non-trainable params: 448
# _________________________________________________________________

# %%
# lr = tf.keras.optimizers.schedules.ExponentialDecay(0.01, decay_steps=20, decay_rate=0.8, staircase=False)
optimizer = tf.keras.optimizers.Adam()
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = tf.keras.metrics.SparseCategoricalAccuracy()

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=[metrics])

# model.compile(optimizer=tf.keras.optimizers.RMSprop(),
#               loss=tf.keras.losses.MeanAbsoluteError(),
#               metrics=tf.keras.losses.MeanSquaredLogarithmicError())

def lr_schedule(epoch):
    if epoch > 350:
        return 0.0001
    if epoch > 200:
        return 0.0005
    if epoch > 150:
        return 0.001
    if epoch > 100:
        return 0.002
    if epoch > 50:
        return 0.005
    return 0.01
        
lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_schedule,verbose=True)

history = model.fit(train_ds,
                    epochs=epoch,
                    validation_data=test_ds,
                    callbacks=[lr_callback])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/500
# 2023-07-21 13:32:09.567122: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-07-21 13:32:09.567326: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - ETA: 0s - loss: 1.4729 - sparse_categorical_accuracy: 0.4249
# 2023-07-21 13:32:12.897528: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 4s 83ms/step - loss: 1.4729 - sparse_categorical_accuracy: 0.4249 - val_loss: 20.3811 - val_sparse_categorical_accuracy: 0.0690 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2529 - sparse_categorical_accuracy: 0.4623 - val_loss: 4.8062 - val_sparse_categorical_accuracy: 0.0690 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2431 - sparse_categorical_accuracy: 0.4637 - val_loss: 1.8592 - val_sparse_categorical_accuracy: 0.0690 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2413 - sparse_categorical_accuracy: 0.4647 - val_loss: 1.4589 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2437 - sparse_categorical_accuracy: 0.4594 - val_loss: 1.2493 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2349 - sparse_categorical_accuracy: 0.4644 - val_loss: 1.5574 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2255 - sparse_categorical_accuracy: 0.4655 - val_loss: 1.3201 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.01.
# Epoch 8/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2238 - sparse_categorical_accuracy: 0.4637 - val_loss: 1.2439 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.01.
# Epoch 9/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2236 - sparse_categorical_accuracy: 0.4587 - val_loss: 1.3028 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.01.
# Epoch 10/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2161 - sparse_categorical_accuracy: 0.4701 - val_loss: 1.2531 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0100
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.01.
# Epoch 11/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2100 - sparse_categorical_accuracy: 0.4694 - val_loss: 1.2824 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.01.
# Epoch 12/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2124 - sparse_categorical_accuracy: 0.4612 - val_loss: 1.2142 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.01.
# Epoch 13/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.2082 - sparse_categorical_accuracy: 0.4601 - val_loss: 1.2168 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.01.
# Epoch 14/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2075 - sparse_categorical_accuracy: 0.4633 - val_loss: 1.2320 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.01.
# Epoch 15/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2084 - sparse_categorical_accuracy: 0.4662 - val_loss: 1.2446 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.01.
# Epoch 16/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2008 - sparse_categorical_accuracy: 0.4765 - val_loss: 1.2430 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0100
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.01.
# Epoch 17/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2047 - sparse_categorical_accuracy: 0.4683 - val_loss: 1.2447 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.01.
# Epoch 18/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2126 - sparse_categorical_accuracy: 0.4558 - val_loss: 1.1995 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0100
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.01.
# Epoch 19/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2099 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.2664 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0100
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.01.
# Epoch 20/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1945 - sparse_categorical_accuracy: 0.4765 - val_loss: 1.3987 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.01.
# Epoch 21/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1972 - sparse_categorical_accuracy: 0.4747 - val_loss: 1.2546 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.01.
# Epoch 22/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1962 - sparse_categorical_accuracy: 0.4669 - val_loss: 1.2411 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.01.
# Epoch 23/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1932 - sparse_categorical_accuracy: 0.4747 - val_loss: 1.2415 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.01.
# Epoch 24/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1963 - sparse_categorical_accuracy: 0.4701 - val_loss: 1.2258 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.01.
# Epoch 25/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1977 - sparse_categorical_accuracy: 0.4605 - val_loss: 1.2330 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.01.
# Epoch 26/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1895 - sparse_categorical_accuracy: 0.4733 - val_loss: 1.2072 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.01.
# Epoch 27/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1893 - sparse_categorical_accuracy: 0.4669 - val_loss: 1.3087 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.01.
# Epoch 28/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1944 - sparse_categorical_accuracy: 0.4633 - val_loss: 1.2589 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.01.
# Epoch 29/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1905 - sparse_categorical_accuracy: 0.4783 - val_loss: 1.2374 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.01.
# Epoch 30/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1895 - sparse_categorical_accuracy: 0.4708 - val_loss: 1.2581 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0100
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.01.
# Epoch 31/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1822 - sparse_categorical_accuracy: 0.4797 - val_loss: 1.2384 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.01.
# Epoch 32/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1851 - sparse_categorical_accuracy: 0.4769 - val_loss: 1.2764 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.01.
# Epoch 33/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1868 - sparse_categorical_accuracy: 0.4662 - val_loss: 1.2239 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.01.
# Epoch 34/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1840 - sparse_categorical_accuracy: 0.4704 - val_loss: 1.3269 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.01.
# Epoch 35/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1887 - sparse_categorical_accuracy: 0.4672 - val_loss: 1.2715 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.01.
# Epoch 36/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1835 - sparse_categorical_accuracy: 0.4747 - val_loss: 1.2346 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0100
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.01.
# Epoch 37/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1815 - sparse_categorical_accuracy: 0.4733 - val_loss: 1.2837 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.01.
# Epoch 38/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1801 - sparse_categorical_accuracy: 0.4797 - val_loss: 1.2245 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0100
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.01.
# Epoch 39/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1794 - sparse_categorical_accuracy: 0.4640 - val_loss: 1.2518 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.01.
# Epoch 40/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1804 - sparse_categorical_accuracy: 0.4672 - val_loss: 1.2457 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.01.
# Epoch 41/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1827 - sparse_categorical_accuracy: 0.4751 - val_loss: 1.2382 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0100
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.01.
# Epoch 42/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1774 - sparse_categorical_accuracy: 0.4801 - val_loss: 1.2131 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.01.
# Epoch 43/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1734 - sparse_categorical_accuracy: 0.4786 - val_loss: 1.2369 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.01.
# Epoch 44/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1727 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.2385 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0100
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.01.
# Epoch 45/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1770 - sparse_categorical_accuracy: 0.4772 - val_loss: 1.2219 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0100
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.01.
# Epoch 46/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1711 - sparse_categorical_accuracy: 0.4797 - val_loss: 1.2297 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.01.
# Epoch 47/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1683 - sparse_categorical_accuracy: 0.4808 - val_loss: 1.2182 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.01.
# Epoch 48/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1654 - sparse_categorical_accuracy: 0.4754 - val_loss: 1.2204 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0100
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.01.
# Epoch 49/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1704 - sparse_categorical_accuracy: 0.4886 - val_loss: 1.2480 - val_sparse_categorical_accuracy: 0.6207 - lr: 0.0100
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.01.
# Epoch 50/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1674 - sparse_categorical_accuracy: 0.4665 - val_loss: 1.2284 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.01.
# Epoch 51/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1677 - sparse_categorical_accuracy: 0.4733 - val_loss: 1.2902 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.005.
# Epoch 52/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1524 - sparse_categorical_accuracy: 0.4932 - val_loss: 1.2421 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.005.
# Epoch 53/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1489 - sparse_categorical_accuracy: 0.4833 - val_loss: 1.2653 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.005.
# Epoch 54/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1379 - sparse_categorical_accuracy: 0.4850 - val_loss: 1.2848 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.005.
# Epoch 55/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1393 - sparse_categorical_accuracy: 0.4915 - val_loss: 1.2683 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0050
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.005.
# Epoch 56/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1369 - sparse_categorical_accuracy: 0.4847 - val_loss: 1.2136 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.005.
# Epoch 57/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1381 - sparse_categorical_accuracy: 0.4925 - val_loss: 1.2411 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.005.
# Epoch 58/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1407 - sparse_categorical_accuracy: 0.4943 - val_loss: 1.2617 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.005.
# Epoch 59/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1356 - sparse_categorical_accuracy: 0.4968 - val_loss: 1.2530 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.005.
# Epoch 60/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1380 - sparse_categorical_accuracy: 0.4947 - val_loss: 1.2857 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.005.
# Epoch 61/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1276 - sparse_categorical_accuracy: 0.4904 - val_loss: 1.2361 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.005.
# Epoch 62/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1281 - sparse_categorical_accuracy: 0.4957 - val_loss: 1.2667 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.005.
# Epoch 63/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1262 - sparse_categorical_accuracy: 0.5043 - val_loss: 1.2888 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.005.
# Epoch 64/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1303 - sparse_categorical_accuracy: 0.4932 - val_loss: 1.2725 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.005.
# Epoch 65/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1334 - sparse_categorical_accuracy: 0.4950 - val_loss: 1.2489 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.005.
# Epoch 66/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1267 - sparse_categorical_accuracy: 0.5018 - val_loss: 1.2790 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.005.
# Epoch 67/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1166 - sparse_categorical_accuracy: 0.4947 - val_loss: 1.2563 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.005.
# Epoch 68/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.1186 - sparse_categorical_accuracy: 0.4989 - val_loss: 1.2479 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.005.
# Epoch 69/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1119 - sparse_categorical_accuracy: 0.5014 - val_loss: 1.2424 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.005.
# Epoch 70/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1095 - sparse_categorical_accuracy: 0.5078 - val_loss: 1.2660 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.005.
# Epoch 71/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1067 - sparse_categorical_accuracy: 0.5142 - val_loss: 1.2469 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.005.
# Epoch 72/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0987 - sparse_categorical_accuracy: 0.5210 - val_loss: 1.3343 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.005.
# Epoch 73/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1088 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.2704 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0050
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.005.
# Epoch 74/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1067 - sparse_categorical_accuracy: 0.5103 - val_loss: 1.3022 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.005.
# Epoch 75/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1034 - sparse_categorical_accuracy: 0.5085 - val_loss: 1.4002 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.005.
# Epoch 76/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1008 - sparse_categorical_accuracy: 0.5050 - val_loss: 1.2485 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.005.
# Epoch 77/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0962 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.3456 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.005.
# Epoch 78/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0906 - sparse_categorical_accuracy: 0.5199 - val_loss: 1.2844 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0050
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.005.
# Epoch 79/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0775 - sparse_categorical_accuracy: 0.5292 - val_loss: 1.3380 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.005.
# Epoch 80/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0828 - sparse_categorical_accuracy: 0.5224 - val_loss: 1.3469 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.005.
# Epoch 81/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0886 - sparse_categorical_accuracy: 0.5260 - val_loss: 1.3892 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.005.
# Epoch 82/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0844 - sparse_categorical_accuracy: 0.5142 - val_loss: 1.3826 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0050
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.005.
# Epoch 83/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0868 - sparse_categorical_accuracy: 0.5267 - val_loss: 1.3539 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.005.
# Epoch 84/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0883 - sparse_categorical_accuracy: 0.5235 - val_loss: 1.2856 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.005.
# Epoch 85/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0621 - sparse_categorical_accuracy: 0.5353 - val_loss: 1.2788 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.005.
# Epoch 86/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0706 - sparse_categorical_accuracy: 0.5274 - val_loss: 1.3722 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.005.
# Epoch 87/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0731 - sparse_categorical_accuracy: 0.5160 - val_loss: 1.3355 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.005.
# Epoch 88/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0654 - sparse_categorical_accuracy: 0.5445 - val_loss: 1.3555 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.005.
# Epoch 89/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0679 - sparse_categorical_accuracy: 0.5442 - val_loss: 1.2864 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.005.
# Epoch 90/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0423 - sparse_categorical_accuracy: 0.5456 - val_loss: 1.3571 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0050
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.005.
# Epoch 91/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0388 - sparse_categorical_accuracy: 0.5520 - val_loss: 1.3655 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.005.
# Epoch 92/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0639 - sparse_categorical_accuracy: 0.5242 - val_loss: 1.4991 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.005.
# Epoch 93/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0418 - sparse_categorical_accuracy: 0.5413 - val_loss: 1.3098 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.005.
# Epoch 94/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0360 - sparse_categorical_accuracy: 0.5363 - val_loss: 1.3959 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0050
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.005.
# Epoch 95/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0458 - sparse_categorical_accuracy: 0.5353 - val_loss: 1.3494 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.005.
# Epoch 96/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0471 - sparse_categorical_accuracy: 0.5431 - val_loss: 1.3385 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.005.
# Epoch 97/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0511 - sparse_categorical_accuracy: 0.5420 - val_loss: 1.4364 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.005.
# Epoch 98/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0255 - sparse_categorical_accuracy: 0.5470 - val_loss: 1.3534 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.005.
# Epoch 99/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0326 - sparse_categorical_accuracy: 0.5470 - val_loss: 1.3377 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.005.
# Epoch 100/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0187 - sparse_categorical_accuracy: 0.5495 - val_loss: 1.3962 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0050
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.005.
# Epoch 101/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.0170 - sparse_categorical_accuracy: 0.5605 - val_loss: 1.4450 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0050
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.002.
# Epoch 102/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9730 - sparse_categorical_accuracy: 0.5798 - val_loss: 1.4331 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.002.
# Epoch 103/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.9563 - sparse_categorical_accuracy: 0.5908 - val_loss: 1.4524 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.002.
# Epoch 104/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9491 - sparse_categorical_accuracy: 0.5915 - val_loss: 1.4158 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.002.
# Epoch 105/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9381 - sparse_categorical_accuracy: 0.5951 - val_loss: 1.4012 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.002.
# Epoch 106/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9302 - sparse_categorical_accuracy: 0.6047 - val_loss: 1.4436 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.002.
# Epoch 107/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9229 - sparse_categorical_accuracy: 0.6026 - val_loss: 1.4250 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.002.
# Epoch 108/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9159 - sparse_categorical_accuracy: 0.6115 - val_loss: 1.4570 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.002.
# Epoch 109/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9123 - sparse_categorical_accuracy: 0.6068 - val_loss: 1.4479 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.002.
# Epoch 110/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9110 - sparse_categorical_accuracy: 0.6111 - val_loss: 1.5253 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.002.
# Epoch 111/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9075 - sparse_categorical_accuracy: 0.6189 - val_loss: 1.5571 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.002.
# Epoch 112/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9058 - sparse_categorical_accuracy: 0.6111 - val_loss: 1.4837 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.002.
# Epoch 113/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9092 - sparse_categorical_accuracy: 0.6083 - val_loss: 1.5023 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.002.
# Epoch 114/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8959 - sparse_categorical_accuracy: 0.6047 - val_loss: 1.5318 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.002.
# Epoch 115/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8936 - sparse_categorical_accuracy: 0.6193 - val_loss: 1.5677 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.002.
# Epoch 116/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8943 - sparse_categorical_accuracy: 0.6054 - val_loss: 1.6745 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.002.
# Epoch 117/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8943 - sparse_categorical_accuracy: 0.6189 - val_loss: 1.5551 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.002.
# Epoch 118/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8751 - sparse_categorical_accuracy: 0.6182 - val_loss: 1.4921 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.002.
# Epoch 119/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8674 - sparse_categorical_accuracy: 0.6204 - val_loss: 1.4821 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.002.
# Epoch 120/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8758 - sparse_categorical_accuracy: 0.6239 - val_loss: 1.5507 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.002.
# Epoch 121/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8685 - sparse_categorical_accuracy: 0.6218 - val_loss: 1.4586 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.002.
# Epoch 122/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8544 - sparse_categorical_accuracy: 0.6303 - val_loss: 1.5191 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.002.
# Epoch 123/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8486 - sparse_categorical_accuracy: 0.6239 - val_loss: 1.5645 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.002.
# Epoch 124/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8594 - sparse_categorical_accuracy: 0.6254 - val_loss: 1.5969 - val_sparse_categorical_accuracy: 0.2069 - lr: 0.0020
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.002.
# Epoch 125/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8327 - sparse_categorical_accuracy: 0.6375 - val_loss: 1.5560 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.002.
# Epoch 126/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8242 - sparse_categorical_accuracy: 0.6485 - val_loss: 1.6904 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.002.
# Epoch 127/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.8276 - sparse_categorical_accuracy: 0.6464 - val_loss: 1.5871 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.002.
# Epoch 128/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8399 - sparse_categorical_accuracy: 0.6471 - val_loss: 1.6073 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.002.
# Epoch 129/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8263 - sparse_categorical_accuracy: 0.6489 - val_loss: 1.6000 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.002.
# Epoch 130/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8108 - sparse_categorical_accuracy: 0.6478 - val_loss: 1.6777 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.002.
# Epoch 131/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8128 - sparse_categorical_accuracy: 0.6531 - val_loss: 1.7174 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.002.
# Epoch 132/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8230 - sparse_categorical_accuracy: 0.6499 - val_loss: 1.6778 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.002.
# Epoch 133/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8088 - sparse_categorical_accuracy: 0.6531 - val_loss: 1.5843 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.002.
# Epoch 134/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.6521 - val_loss: 1.7035 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.002.
# Epoch 135/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7907 - sparse_categorical_accuracy: 0.6535 - val_loss: 1.7419 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.002.
# Epoch 136/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7804 - sparse_categorical_accuracy: 0.6652 - val_loss: 1.7104 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.002.
# Epoch 137/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7569 - sparse_categorical_accuracy: 0.6834 - val_loss: 1.8202 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.002.
# Epoch 138/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7754 - sparse_categorical_accuracy: 0.6684 - val_loss: 1.6575 - val_sparse_categorical_accuracy: 0.2414 - lr: 0.0020
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.002.
# Epoch 139/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7605 - sparse_categorical_accuracy: 0.6806 - val_loss: 1.7058 - val_sparse_categorical_accuracy: 0.2414 - lr: 0.0020
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.002.
# Epoch 140/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7646 - sparse_categorical_accuracy: 0.6784 - val_loss: 1.8528 - val_sparse_categorical_accuracy: 0.2414 - lr: 0.0020
#
# Epoch 141: LearningRateScheduler setting learning rate to 0.002.
# Epoch 141/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7538 - sparse_categorical_accuracy: 0.6902 - val_loss: 1.7155 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.002.
# Epoch 142/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7267 - sparse_categorical_accuracy: 0.6877 - val_loss: 1.7434 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.002.
# Epoch 143/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7419 - sparse_categorical_accuracy: 0.6944 - val_loss: 1.7307 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.002.
# Epoch 144/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7311 - sparse_categorical_accuracy: 0.6895 - val_loss: 1.9394 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.002.
# Epoch 145/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7259 - sparse_categorical_accuracy: 0.6909 - val_loss: 1.9023 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.002.
# Epoch 146/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7075 - sparse_categorical_accuracy: 0.7151 - val_loss: 1.8867 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.002.
# Epoch 147/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7017 - sparse_categorical_accuracy: 0.6976 - val_loss: 1.7429 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.002.
# Epoch 148/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7123 - sparse_categorical_accuracy: 0.6984 - val_loss: 1.8085 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.002.
# Epoch 149/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7099 - sparse_categorical_accuracy: 0.7001 - val_loss: 1.8330 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.002.
# Epoch 150/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.6969 - sparse_categorical_accuracy: 0.6994 - val_loss: 1.9670 - val_sparse_categorical_accuracy: 0.2414 - lr: 0.0020
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.002.
# Epoch 151/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.6767 - sparse_categorical_accuracy: 0.7144 - val_loss: 1.9579 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.001.
# Epoch 152/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.6529 - sparse_categorical_accuracy: 0.7368 - val_loss: 1.9250 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.001.
# Epoch 153/500
# 22/22 [==============================] - 1s 46ms/step - loss: 0.6251 - sparse_categorical_accuracy: 0.7475 - val_loss: 1.8578 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.001.
# Epoch 154/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6230 - sparse_categorical_accuracy: 0.7457 - val_loss: 1.8761 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.001.
# Epoch 155/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6196 - sparse_categorical_accuracy: 0.7443 - val_loss: 1.9089 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.001.
# Epoch 156/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6103 - sparse_categorical_accuracy: 0.7479 - val_loss: 1.9551 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.001.
# Epoch 157/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6194 - sparse_categorical_accuracy: 0.7457 - val_loss: 2.0029 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.001.
# Epoch 158/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6017 - sparse_categorical_accuracy: 0.7493 - val_loss: 1.8750 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0010
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.001.
# Epoch 159/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5934 - sparse_categorical_accuracy: 0.7525 - val_loss: 2.1818 - val_sparse_categorical_accuracy: 0.2414 - lr: 0.0010
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.001.
# Epoch 160/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5907 - sparse_categorical_accuracy: 0.7472 - val_loss: 2.1183 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.001.
# Epoch 161/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5830 - sparse_categorical_accuracy: 0.7646 - val_loss: 2.0702 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.001.
# Epoch 162/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.5722 - sparse_categorical_accuracy: 0.7685 - val_loss: 1.9766 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.001.
# Epoch 163/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5749 - sparse_categorical_accuracy: 0.7575 - val_loss: 1.9946 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.001.
# Epoch 164/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5763 - sparse_categorical_accuracy: 0.7596 - val_loss: 2.0049 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.001.
# Epoch 165/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5739 - sparse_categorical_accuracy: 0.7603 - val_loss: 2.0137 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.001.
# Epoch 166/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5734 - sparse_categorical_accuracy: 0.7657 - val_loss: 2.0923 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0010
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.001.
# Epoch 167/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5452 - sparse_categorical_accuracy: 0.7888 - val_loss: 2.0797 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.001.
# Epoch 168/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5507 - sparse_categorical_accuracy: 0.7760 - val_loss: 2.1097 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.001.
# Epoch 169/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.5459 - sparse_categorical_accuracy: 0.7817 - val_loss: 2.2084 - val_sparse_categorical_accuracy: 0.2069 - lr: 0.0010
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.001.
# Epoch 170/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.5655 - sparse_categorical_accuracy: 0.7667 - val_loss: 2.2024 - val_sparse_categorical_accuracy: 0.2069 - lr: 0.0010
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.001.
# Epoch 171/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.5317 - sparse_categorical_accuracy: 0.7813 - val_loss: 2.1079 - val_sparse_categorical_accuracy: 0.1724 - lr: 0.0010
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.001.
# Epoch 172/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5317 - sparse_categorical_accuracy: 0.7785 - val_loss: 2.2247 - val_sparse_categorical_accuracy: 0.2069 - lr: 0.0010
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.001.
# Epoch 173/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.5357 - sparse_categorical_accuracy: 0.7796 - val_loss: 1.9742 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.001.
# Epoch 174/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.5297 - sparse_categorical_accuracy: 0.7870 - val_loss: 2.1542 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.001.
# Epoch 175/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.5252 - sparse_categorical_accuracy: 0.7817 - val_loss: 2.1586 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.001.
# Epoch 176/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5189 - sparse_categorical_accuracy: 0.7867 - val_loss: 2.2513 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.001.
# Epoch 177/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5214 - sparse_categorical_accuracy: 0.7817 - val_loss: 2.1208 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.001.
# Epoch 178/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5153 - sparse_categorical_accuracy: 0.7913 - val_loss: 2.2077 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.001.
# Epoch 179/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5086 - sparse_categorical_accuracy: 0.7991 - val_loss: 2.1261 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.001.
# Epoch 180/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.4988 - sparse_categorical_accuracy: 0.8034 - val_loss: 2.1903 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.001.
# Epoch 181/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5148 - sparse_categorical_accuracy: 0.7877 - val_loss: 2.1729 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.001.
# Epoch 182/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.4922 - sparse_categorical_accuracy: 0.7984 - val_loss: 2.2726 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.001.
# Epoch 183/500
# ...
#
# Epoch 441: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 441/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1348 - sparse_categorical_accuracy: 0.9519 - val_loss: 3.0092 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 442: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 442/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1248 - sparse_categorical_accuracy: 0.9630 - val_loss: 3.0378 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 443: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 443/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9580 - val_loss: 3.0099 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 444: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 444/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1278 - sparse_categorical_accuracy: 0.9590 - val_loss: 2.9990 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 445: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 445/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1204 - sparse_categorical_accuracy: 0.9637 - val_loss: 2.9743 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 446: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 446/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1230 - sparse_categorical_accuracy: 0.9640 - val_loss: 2.9660 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 447: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 447/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1281 - sparse_categorical_accuracy: 0.9615 - val_loss: 2.9711 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 448: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 448/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1232 - sparse_categorical_accuracy: 0.9605 - val_loss: 2.9739 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 449: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 449/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1250 - sparse_categorical_accuracy: 0.9605 - val_loss: 3.0230 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 450: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 450/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1280 - sparse_categorical_accuracy: 0.9598 - val_loss: 3.0020 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 451: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 451/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1358 - sparse_categorical_accuracy: 0.9558 - val_loss: 2.9826 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 452: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 452/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1126 - sparse_categorical_accuracy: 0.9619 - val_loss: 2.9628 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 453: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 453/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1183 - sparse_categorical_accuracy: 0.9633 - val_loss: 2.9572 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 454: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 454/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1280 - sparse_categorical_accuracy: 0.9558 - val_loss: 2.9592 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 455: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 455/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1232 - sparse_categorical_accuracy: 0.9633 - val_loss: 2.9409 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 456: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 456/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1247 - sparse_categorical_accuracy: 0.9590 - val_loss: 2.9071 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 457: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 457/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1161 - sparse_categorical_accuracy: 0.9637 - val_loss: 2.8672 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 458: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 458/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1256 - sparse_categorical_accuracy: 0.9580 - val_loss: 2.8708 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 459: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 459/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1178 - sparse_categorical_accuracy: 0.9665 - val_loss: 2.9077 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 460: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 460/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1394 - sparse_categorical_accuracy: 0.9526 - val_loss: 2.9179 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 461: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 461/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1332 - sparse_categorical_accuracy: 0.9551 - val_loss: 2.9417 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 462: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 462/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1212 - sparse_categorical_accuracy: 0.9623 - val_loss: 2.9551 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 463: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 463/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1219 - sparse_categorical_accuracy: 0.9612 - val_loss: 2.9495 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 464: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 464/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9544 - val_loss: 3.0140 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 465: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 465/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1233 - sparse_categorical_accuracy: 0.9612 - val_loss: 3.0446 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 466: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 466/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1145 - sparse_categorical_accuracy: 0.9697 - val_loss: 3.0765 - val_sparse_categorical_accuracy: 0.4483 - lr: 1.0000e-04
#
# Epoch 467: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 467/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1281 - sparse_categorical_accuracy: 0.9576 - val_loss: 3.0477 - val_sparse_categorical_accuracy: 0.4483 - lr: 1.0000e-04
#
# Epoch 468: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 468/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1154 - sparse_categorical_accuracy: 0.9651 - val_loss: 2.9904 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 469: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 469/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1221 - sparse_categorical_accuracy: 0.9633 - val_loss: 2.9679 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 470: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 470/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1362 - sparse_categorical_accuracy: 0.9551 - val_loss: 2.9497 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 471: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 471/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1058 - sparse_categorical_accuracy: 0.9669 - val_loss: 3.0002 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 472: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 472/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1143 - sparse_categorical_accuracy: 0.9637 - val_loss: 3.0606 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 473: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 473/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1104 - sparse_categorical_accuracy: 0.9683 - val_loss: 3.0319 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 474: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 474/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1209 - sparse_categorical_accuracy: 0.9626 - val_loss: 3.0178 - val_sparse_categorical_accuracy: 0.4483 - lr: 1.0000e-04
#
# Epoch 475: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 475/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1253 - sparse_categorical_accuracy: 0.9615 - val_loss: 3.0162 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 476: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 476/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1111 - sparse_categorical_accuracy: 0.9655 - val_loss: 2.9633 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 477: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 477/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1246 - sparse_categorical_accuracy: 0.9580 - val_loss: 2.9950 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 478: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 478/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1279 - sparse_categorical_accuracy: 0.9580 - val_loss: 2.9527 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 479: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 479/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1396 - sparse_categorical_accuracy: 0.9494 - val_loss: 2.9661 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 480: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 480/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1101 - sparse_categorical_accuracy: 0.9655 - val_loss: 2.9925 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 481: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 481/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1133 - sparse_categorical_accuracy: 0.9637 - val_loss: 2.9887 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 482: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 482/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1246 - sparse_categorical_accuracy: 0.9583 - val_loss: 2.9937 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 483: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 483/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1276 - sparse_categorical_accuracy: 0.9551 - val_loss: 2.9402 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 484: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 484/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9612 - val_loss: 2.9557 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 485: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 485/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1233 - sparse_categorical_accuracy: 0.9615 - val_loss: 3.0249 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 486: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 486/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1052 - sparse_categorical_accuracy: 0.9697 - val_loss: 3.0616 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 487: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 487/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1325 - sparse_categorical_accuracy: 0.9551 - val_loss: 3.0324 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 488: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 488/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1157 - sparse_categorical_accuracy: 0.9672 - val_loss: 3.0378 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 489: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 489/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1114 - sparse_categorical_accuracy: 0.9676 - val_loss: 3.0287 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 490: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 490/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1295 - sparse_categorical_accuracy: 0.9537 - val_loss: 3.0114 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 491: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 491/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1162 - sparse_categorical_accuracy: 0.9608 - val_loss: 3.0193 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 492: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 492/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1104 - sparse_categorical_accuracy: 0.9658 - val_loss: 3.0594 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 493: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 493/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1206 - sparse_categorical_accuracy: 0.9558 - val_loss: 3.0673 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 494: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 494/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1193 - sparse_categorical_accuracy: 0.9587 - val_loss: 3.0108 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 495: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 495/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1193 - sparse_categorical_accuracy: 0.9615 - val_loss: 3.0335 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 496: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 496/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1154 - sparse_categorical_accuracy: 0.9658 - val_loss: 2.9779 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 497: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 497/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1139 - sparse_categorical_accuracy: 0.9605 - val_loss: 2.9791 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 498: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 498/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1181 - sparse_categorical_accuracy: 0.9637 - val_loss: 2.9949 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 499: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 499/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1091 - sparse_categorical_accuracy: 0.9655 - val_loss: 2.9960 - val_sparse_categorical_accuracy: 0.4828 - lr: 1.0000e-04
#
# Epoch 500: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 500/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1156 - sparse_categorical_accuracy: 0.9587 - val_loss: 3.0134 - val_sparse_categorical_accuracy: 0.4483 - lr: 1.0000e-04

# %%
train_acc = history.history['sparse_categorical_accuracy']
train_loss = history.history['loss']

val_acc = history.history['val_sparse_categorical_accuracy']
val_loss = history.history['val_loss']

plt.figure()
plt.plot(range(epoch), train_loss, label='train_loss')
plt.plot(range(epoch), val_loss, label='val_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

plt.figure()
plt.plot(range(epoch), train_acc, label='train_acc')
plt.plot(range(epoch), val_acc, label='val_acc')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('msle')
plt.show()

# %%
model.evaluate(test_ds)

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)

df_time = date[-len(y_test):]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, y_test, 'b-', label='actual')
axes.plot(df_time, y_pred, 'r--', label='predict')
print(y_pred)
axes.set_xticks(df_time[::1])
axes.set_xticklabels(df_time[::1],rotation=45)

plt.legend()
plt.grid()
plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step - loss: 3.0134 - sparse_categorical_accuracy: 0.4483
# 1/1 [==============================] - 0s 178ms/step
# [5 5 5 5 5 3 4 4 3 4 5 4 4 3 5 5 2 4 5 3 2 5 5 4 4 5 4 4 5]
# 2023-07-21 13:38:44.143760: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
price_actual = list()
price_pred = list()
price_actual.append(1.0)
price_pred.append(1.0)
    

for idx in range(1, len(y_test)):
    price_actual.append(price_actual[idx-1] * change_test[idx])
    price_pred.append(price_pred[idx-1] * label2change(y_pred[idx]))
print(price_actual)
print(price_pred)
# Out:
# [1.0, 1.0021977424621582, 0.9978021550964513, 1.0703295490642146, 1.0659339624585153, 1.0439559413040178, 1.0417581053935308, 1.054945052045385, 1.0417581257114925, 1.024175695415759, 0.980219668513828, 1.0197800233944425, 1.0835162748565952, 1.0593405525378703, 1.0923075486453682, 1.0923075486453682, 1.0791207269749712, 1.109890033315542, 1.1230768945862628, 1.1010988900646868, 1.0901098322880776, 1.1670328967470367, 1.2065932513953992, 1.1450548391680666, 1.2175822808848387, 1.3054944071347725, 1.2043954890251036, 1.2879119938852652, 1.417582189377483]
# [1.0, 1.1, 1.2100000000000002, 1.3310000000000004, 1.4641000000000006, 1.4201770000000005, 1.4059752300000004, 1.3919154777000002, 1.350158013369, 1.3366564332353101, 1.4703220765588412, 1.4556188557932528, 1.4410626672353202, 1.3978307872182605, 1.5376138659400866, 1.6913752525340955, 1.6068064899073906, 1.5907384250083167, 1.7498122675091485, 1.697317899483874, 1.6124520045096802, 1.7736972049606483, 1.9510669254567132, 1.931556256202146, 1.9122406936401246, 2.1034647630041374, 2.082430115374096, 2.0616058142203553, 2.267766395642391]

# %%
df_time = date[-len(y_test):]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, price_actual, 'b-', label='actual')
axes.plot(df_time, price_pred, 'r--', label='predict')

axes.set_xticks(df_time[::1])
axes.set_xticklabels(df_time[::1],rotation=45)

plt.legend()
plt.grid()
plt.show()

# %%
actual_profit_rate = 1
for idx in range(0, len(y_pred)):
    if y_pred[idx] >= 1:
        actual_profit_rate *= change_test[idx]
print(actual_profit_rate)
# Out:
# 1.4052285045252226

# %%
predict_train = model.predict(x_train)
predict_train = np.argmax(predict_train, axis=1)

df_time = date[mem_his_days + pre_days - 1 :mem_his_days + pre_days - 1 + len(predict_train)]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, y_train, 'b-', label='actual')
print(predict_train.shape)
axes.plot(df_time, predict_train, 'r--', label='predict')

axes.set_xticks(df_time[::100])
axes.set_xticklabels(df_time[::100],rotation=45)

plt.legend()
plt.grid()
plt.show()
# Out:
# 88/88 [==============================] - 1s 10ms/step
# (2808,)

# %%
predict_x = np.array(predict_x).reshape(-1,num_feature * mem_his_days,1)
predict = model.predict(predict_x)
predict = np.argmax(predict, axis=1)

def up_or_down(pred):
    if pred >= 3:
        return '↗'
    return '↘'
print('Current code is ' + stock_code + ', current date is ' + newest_data)
print('T+1 ' + up_or_down(predict[0]))
print('T+2 ' + up_or_down(predict[1]))
# Out:
# 1/1 [==============================] - 0s 148ms/step
# Current code is 002316, current date is 2023-07-20
# T+1 ↘
# T+2 ↘
