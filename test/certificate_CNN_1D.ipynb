# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import happybase
import collections
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.9.2
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
pre_days = 2
mem_his_days = 10
num_feature = 17
epoch = 500
train_rate = 0.99
batch_size = 128
table_name = 'certificate'
column_family = 'feature'
stock_code = '002316'

# %%
def change2label(x):
    if x < 0.92:
       return 0
    elif x < 0.94:
       return 1
    elif x < 0.96:
       return 2
    elif x < 0.98:
       return 3
    elif x < 1.:
       return 4
    elif x < 1.2:
       return 5
    elif x < 1.4:
       return 6
    elif x < 1.6:
       return 7
    elif x < 1.8:
       return 8
    return 9

def label2change(label):
    if label == 0:
        return 0.91
    elif label == 1:
        return 0.93
    elif label == 2:
        return 0.95
    elif label == 3:
        return 0.97
    elif label == 4:
        return 0.99
    elif label == 5:
        return 1.1
    elif label == 6:
        return 1.3
    elif label == 7:
        return 1.5
    elif label == 8:
        return 1.7
    return 1.9

# %%
# load features from hbase
connection = happybase.Connection('localhost', 9090, transport='framed', protocol='compact')
connection.open()
table = connection.table(table_name)
rows = table.scan(row_prefix=stock_code.encode('utf-8'))
df = pd.DataFrame()
idx = int(0)
newest_data = '1970-01-01'
for row in rows:
    date = row[0].decode('utf-8').split('_')[-1]
    cells = row[1]
    for column in cells:
        df.at[idx, column.decode('utf-8').split(':')[-1]] = np.float32(cells[column].decode('utf-8'))
    df.at[idx, 'date'] = date
    newest_data = max(date, newest_data)
    
    idx = idx + 1
connection.close()
df.dropna(inplace=True)
df
# Out:
#       macd_dea  macd_diff  macd_ema12  macd_ema26  macd_macd  trade_c  \
# 8       -0.130     -0.836   34.603001   35.439400     -1.412    31.18
# 9       -0.352     -1.241   33.704102   34.944599     -1.776    28.76
# 10      -0.561     -1.397   33.224998   34.622002     -1.672    30.59
# 11      -0.737     -1.439   32.944199   34.383301     -1.405    31.40
# 12      -0.891     -1.508   32.605099   34.113400     -1.234    30.74
# ...        ...        ...         ...         ...        ...      ...
# 2852     0.113      0.165    5.015800    4.851300      0.104     5.54
# 2853     0.129      0.196    5.099500    4.903800      0.133     5.56
# 2854     0.143      0.200    5.135000    4.935400      0.113     5.33
# 2855     0.163      0.243    5.246500    5.003900      0.159     5.86
# 2856     0.195      0.321    5.431700    5.111000      0.252     6.45
#
#           trade_e    trade_h   trade_hs    trade_l    trade_o    trade_v  \
# 8      90117944.0  31.690001  12.060000  30.400000  30.469999    28941.0
# 9     114190072.0  31.080000  16.139999  28.600000  30.889999    38735.0
# 10    155427968.0  31.290001  21.440001  28.690001  28.690001    51455.0
# 11    152094352.0  31.799999  20.629999  29.389999  30.170000    49503.0
# 12     90032200.0  31.389999  12.130000  30.420000  30.500000    29106.0
# ...           ...        ...        ...        ...        ...        ...
# 2852  212349872.0   5.540000  12.510000   5.010000   5.010000   394061.0
# 2853  599063808.0   5.940000  33.700001   5.400000   5.540000  1061622.0
# 2854  313424032.0   5.480000  18.760000   5.200000   5.410000   591018.0
# 2855  271282048.0   5.860000  14.860000   5.230000   5.250000   468242.0
# 2856   70665760.0   6.450000   3.480000   6.450000   6.450000   109559.0
#
#       trade_zd  trade_zde  trade_zf        date      kdj_d       kdj_j  \
# 8         1.53       0.47      4.20  2009-12-21   8.500000    8.500000
# 9        -7.76      -2.42      7.95  2009-12-22   7.680000    2.790000
# 10        6.36       1.83      9.04  2009-12-23   8.030000   10.130000
# 11        2.65       0.81      7.88  2009-12-24   9.880000   20.980000
# 12       -2.10      -0.66      3.09  2009-12-25  12.130000   25.660000
# ...        ...        ...       ...         ...        ...         ...
# 2852      9.92       0.50     10.52  2023-07-14  65.970001   74.309998
# 2853      0.36       0.02      9.75  2023-07-17  66.760002   71.500000
# 2854     -4.14      -0.23      5.04  2023-07-18  65.019997   54.520000
# 2855      9.94       0.53     11.82  2023-07-19  67.360001   81.459999
# 2856     10.07       0.59      0.00  2023-07-20  72.019997  100.040001
#
#           kdj_k
# 8      8.500000
# 9      6.050000
# 10     8.730000
# 11    13.580000
# 12    16.639999
# ...         ...
# 2852  68.750000
# 2853  68.339996
# 2854  61.520000
# 2855  72.059998
# 2856  81.360001
#
# [2849 rows x 19 columns]

# %%
df['PreHigh'] = df['trade_h'].shift(1)
df["Change"] = df['trade_h'] / df['PreHigh']

df = df.dropna()
change = np.array(df['Change']).astype(np.float32)
df['Change'] = df['Change'].apply(change2label)

df = df.drop('trade_h', axis=1)
df = df.drop('PreHigh', axis=1)

date = df['date']
df = df.drop(labels='date', axis=1)

scaler = MinMaxScaler((0, 1))

sca = scaler.fit_transform(df.iloc[:, :-1])
print(scaler.data_max_, scaler.data_min_)
label = np.array(df.iloc[:, -1])
print(sca)
print(label)
print(change)
# Out:
# [2.06299996e+00 2.34999990e+00 3.37041016e+01 3.49445992e+01
#  1.86300004e+00 3.50800018e+01 1.73344512e+09 5.65800018e+01
#  3.36300011e+01 3.50000000e+01 1.66022800e+06 1.01199999e+01
#  2.24000001e+00 1.99500008e+01 9.65899963e+01 1.24339996e+02
#  9.90800018e+01] [-2.39299989e+00 -2.64299989e+00  2.29970002e+00  2.41529989e+00
#  -1.77600002e+00  2.24000001e+00  4.41216000e+05  5.00000007e-02
#   2.21000004e+00  2.22000003e+00  1.53200000e+03 -3.29399986e+01
#  -6.32000017e+00  0.00000000e+00  4.46000004e+00 -2.51299992e+01
#   1.70000005e+00]
# [[0.4580341  0.28079309 1.         ... 0.03495061 0.18679334 0.04467036]
#  [0.41113105 0.24954937 0.98474408 ... 0.03874959 0.23590018 0.07219141]
#  [0.37163374 0.24113758 0.97580266 ... 0.05882992 0.30849    0.1219963 ]
#  ...
#  [0.56912028 0.56939716 0.09028353 ... 0.65733202 0.53288287 0.61429451]
#  [0.57360861 0.57800921 0.09383398 ... 0.68273096 0.7131197  0.72253025]
#  [0.58078994 0.59363109 0.09973125 ... 0.73331162 0.8374256  0.81803244]]
# [4 5 5 ... 1 5 5]
# [0.980751  1.0067568 1.0162991 ... 0.9225589 1.0693431 1.1006825]
# /var/folders/b1/0fd1b6hs7lz0fm_mh346lybm0000gn/T/ipykernel_75084/3599398066.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Change'] = df['Change'].apply(change2label)

# %%
deq = collections.deque()

x = list()
for row in sca:
    deq.append(list(row))
    if len(deq) > mem_his_days:
        deq.popleft()
    if len(deq) == mem_his_days:
        x.append(np.array(deq).reshape(-1, 1))
predict_x = x[-pre_days:]
x = x[:-pre_days]
y = label[mem_his_days + pre_days - 1:]
change = change[mem_his_days + pre_days - 1:]

x, y = np.array(x).reshape(-1, num_feature * mem_his_days, 1), np.array(y)
print(x.shape)
print(y.shape)
# Out:
# (2837, 170, 1)
# (2837,)

# %%
total_num = len(x)
train_num = int(total_num * train_rate)
print(train_num)
# Out:
# 2808

# %%
x_train, y_train, change_train = x[:train_num], y[:train_num], change[:train_num]
x_test, y_test, change_test = x[train_num:], y[train_num:], change[train_num:]

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.shuffle(train_num).batch(batch_size=batch_size).prefetch(tf.data.experimental.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_ds = test_ds.shuffle(total_num - train_num).batch(batch_size=batch_size).prefetch(tf.data.experimental.AUTOTUNE)

sample = next(iter(train_ds))
print('x_train.shape:', sample[0].shape)
print('y_train.shape:', sample[1].shape)
print(change_test)
# Out:
# x_train.shape: (128, 170, 1)
# y_train.shape: (128,)
# [0.9912854  1.0021977  0.99561405 1.0726871  0.99589324 0.97938144
#  0.9978947  1.0126584  0.9874999  0.98312235 0.95708156 1.0403587
#  1.0625     0.9776877  1.0311203  1.         0.98792756 1.0285133
#  1.0118812  0.98043054 0.9900199  1.0705645  1.0338982  0.9489982
#  1.0633397  1.0722022  0.9225589  1.0693431  1.1006825 ]

# %%
input_shape = sample[0].shape[-2:]
print(input_shape)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv1D(32,num_feature * mem_his_days,input_shape=input_shape,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.MaxPooling1D())
model.add(tf.keras.layers.Conv1D(64,num_feature * mem_his_days,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.MaxPooling1D())
model.add(tf.keras.layers.Conv1D(64,num_feature * mem_his_days,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.GlobalAveragePooling1D())
model.add(tf.keras.layers.Dense(64))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dense(10,activation='softmax'))
model.build(input_shape=[None, num_feature * mem_his_days])

model.summary()
# Out:
# (170, 1)
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 170, 32)           5472
#
#  batch_normalization_32 (Bat  (None, 170, 32)          128
#  chNormalization)
#
#  re_lu_32 (ReLU)             (None, 170, 32)           0
#
#  dropout_24 (Dropout)        (None, 170, 32)           0
#
#  max_pooling1d_2 (MaxPooling  (None, 85, 32)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 85, 64)            348224
#
#  batch_normalization_33 (Bat  (None, 85, 64)           256
#  chNormalization)
#
#  re_lu_33 (ReLU)             (None, 85, 64)            0
#
#  dropout_25 (Dropout)        (None, 85, 64)            0
#
#  max_pooling1d_3 (MaxPooling  (None, 42, 64)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 42, 64)            696384
#
#  batch_normalization_34 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  re_lu_34 (ReLU)             (None, 42, 64)            0
#
#  dropout_26 (Dropout)        (None, 42, 64)            0
#
#  global_average_pooling1d_1   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  batch_normalization_35 (Bat  (None, 64)               256
#  chNormalization)
#
#  re_lu_35 (ReLU)             (None, 64)                0
#
#  dense_17 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,055,786
# Trainable params: 1,055,338
# Non-trainable params: 448
# _________________________________________________________________

# %%
# lr = tf.keras.optimizers.schedules.ExponentialDecay(0.01, decay_steps=20, decay_rate=0.8, staircase=False)
optimizer = tf.keras.optimizers.Adam()
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = tf.keras.metrics.SparseCategoricalAccuracy()

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=[metrics])

# model.compile(optimizer=tf.keras.optimizers.RMSprop(),
#               loss=tf.keras.losses.MeanAbsoluteError(),
#               metrics=tf.keras.losses.MeanSquaredLogarithmicError())

def lr_schedule(epoch):
    if epoch > 350:
        return 0.0001
    if epoch > 200:
        return 0.0005
    if epoch > 150:
        return 0.001
    if epoch > 100:
        return 0.002
    if epoch > 50:
        return 0.005
    return 0.01
        
lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_schedule,verbose=True)

history = model.fit(train_ds,
                    epochs=epoch,
                    validation_data=test_ds,
                    callbacks=[lr_callback])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/500
# 2023-07-21 13:17:05.300678: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - ETA: 0s - loss: 1.4980 - sparse_categorical_accuracy: 0.4088
# 2023-07-21 13:17:08.202389: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 4s 98ms/step - loss: 1.4980 - sparse_categorical_accuracy: 0.4088 - val_loss: 19.6669 - val_sparse_categorical_accuracy: 0.2414 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2585 - sparse_categorical_accuracy: 0.4644 - val_loss: 2.0809 - val_sparse_categorical_accuracy: 0.0690 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.2472 - sparse_categorical_accuracy: 0.4676 - val_loss: 1.5283 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2463 - sparse_categorical_accuracy: 0.4615 - val_loss: 1.7198 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2310 - sparse_categorical_accuracy: 0.4690 - val_loss: 1.6347 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.2348 - sparse_categorical_accuracy: 0.4626 - val_loss: 1.5443 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2293 - sparse_categorical_accuracy: 0.4658 - val_loss: 1.4784 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.01.
# Epoch 8/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2243 - sparse_categorical_accuracy: 0.4619 - val_loss: 1.4588 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.01.
# Epoch 9/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.2244 - sparse_categorical_accuracy: 0.4484 - val_loss: 1.5655 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.01.
# Epoch 10/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.2147 - sparse_categorical_accuracy: 0.4640 - val_loss: 1.2372 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.01.
# Epoch 11/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2126 - sparse_categorical_accuracy: 0.4594 - val_loss: 1.3202 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.01.
# Epoch 12/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.2146 - sparse_categorical_accuracy: 0.4651 - val_loss: 1.2913 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0100
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.01.
# Epoch 13/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2180 - sparse_categorical_accuracy: 0.4566 - val_loss: 1.2991 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.01.
# Epoch 14/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.2080 - sparse_categorical_accuracy: 0.4662 - val_loss: 1.1943 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.01.
# Epoch 15/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.2065 - sparse_categorical_accuracy: 0.4676 - val_loss: 1.2473 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.01.
# Epoch 16/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1985 - sparse_categorical_accuracy: 0.4715 - val_loss: 1.2171 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.01.
# Epoch 17/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.2031 - sparse_categorical_accuracy: 0.4665 - val_loss: 1.2920 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.01.
# Epoch 18/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.2052 - sparse_categorical_accuracy: 0.4640 - val_loss: 1.3871 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.01.
# Epoch 19/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.2104 - sparse_categorical_accuracy: 0.4687 - val_loss: 1.2952 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.01.
# Epoch 20/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1998 - sparse_categorical_accuracy: 0.4704 - val_loss: 1.2072 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.01.
# Epoch 21/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1989 - sparse_categorical_accuracy: 0.4726 - val_loss: 1.2746 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.01.
# Epoch 22/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1991 - sparse_categorical_accuracy: 0.4640 - val_loss: 1.1848 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.01.
# Epoch 23/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1977 - sparse_categorical_accuracy: 0.4615 - val_loss: 1.2279 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.01.
# Epoch 24/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1949 - sparse_categorical_accuracy: 0.4776 - val_loss: 1.2662 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.01.
# Epoch 25/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1899 - sparse_categorical_accuracy: 0.4665 - val_loss: 1.2044 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.01.
# Epoch 26/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1861 - sparse_categorical_accuracy: 0.4740 - val_loss: 1.3332 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.01.
# Epoch 27/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1940 - sparse_categorical_accuracy: 0.4665 - val_loss: 1.2455 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.01.
# Epoch 28/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1913 - sparse_categorical_accuracy: 0.4701 - val_loss: 1.2328 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0100
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.01.
# Epoch 29/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1916 - sparse_categorical_accuracy: 0.4708 - val_loss: 1.2911 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.01.
# Epoch 30/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1894 - sparse_categorical_accuracy: 0.4708 - val_loss: 1.2314 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0100
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.01.
# Epoch 31/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1821 - sparse_categorical_accuracy: 0.4751 - val_loss: 1.2142 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.01.
# Epoch 32/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1913 - sparse_categorical_accuracy: 0.4665 - val_loss: 1.2875 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.01.
# Epoch 33/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1839 - sparse_categorical_accuracy: 0.4679 - val_loss: 1.2450 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.01.
# Epoch 34/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1860 - sparse_categorical_accuracy: 0.4779 - val_loss: 1.2038 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.01.
# Epoch 35/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1884 - sparse_categorical_accuracy: 0.4615 - val_loss: 1.2236 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0100
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.01.
# Epoch 36/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1811 - sparse_categorical_accuracy: 0.4715 - val_loss: 1.2738 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.01.
# Epoch 37/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1849 - sparse_categorical_accuracy: 0.4690 - val_loss: 1.3239 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0100
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.01.
# Epoch 38/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1873 - sparse_categorical_accuracy: 0.4669 - val_loss: 1.2299 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.01.
# Epoch 39/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1910 - sparse_categorical_accuracy: 0.4719 - val_loss: 1.2610 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0100
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.01.
# Epoch 40/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1836 - sparse_categorical_accuracy: 0.4687 - val_loss: 1.2341 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.01.
# Epoch 41/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1822 - sparse_categorical_accuracy: 0.4761 - val_loss: 1.3164 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0100
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.01.
# Epoch 42/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1846 - sparse_categorical_accuracy: 0.4854 - val_loss: 1.2185 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.01.
# Epoch 43/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1815 - sparse_categorical_accuracy: 0.4797 - val_loss: 1.2561 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.01.
# Epoch 44/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1808 - sparse_categorical_accuracy: 0.4679 - val_loss: 1.2134 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.01.
# Epoch 45/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1751 - sparse_categorical_accuracy: 0.4797 - val_loss: 1.2503 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.01.
# Epoch 46/500
# 22/22 [==============================] - 1s 35ms/step - loss: 1.1741 - sparse_categorical_accuracy: 0.4840 - val_loss: 1.2084 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.01.
# Epoch 47/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1727 - sparse_categorical_accuracy: 0.4868 - val_loss: 1.2274 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.01.
# Epoch 48/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1749 - sparse_categorical_accuracy: 0.4776 - val_loss: 1.2825 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.01.
# Epoch 49/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1753 - sparse_categorical_accuracy: 0.4825 - val_loss: 1.2344 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.01.
# Epoch 50/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1741 - sparse_categorical_accuracy: 0.4704 - val_loss: 1.2635 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.01.
# Epoch 51/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1635 - sparse_categorical_accuracy: 0.4850 - val_loss: 1.2257 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.005.
# Epoch 52/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1546 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.2543 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.005.
# Epoch 53/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1517 - sparse_categorical_accuracy: 0.4968 - val_loss: 1.2244 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.005.
# Epoch 54/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1473 - sparse_categorical_accuracy: 0.4907 - val_loss: 1.2389 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.005.
# Epoch 55/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1432 - sparse_categorical_accuracy: 0.4932 - val_loss: 1.2896 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.005.
# Epoch 56/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1417 - sparse_categorical_accuracy: 0.4879 - val_loss: 1.2405 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.005.
# Epoch 57/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1452 - sparse_categorical_accuracy: 0.4972 - val_loss: 1.2692 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.005.
# Epoch 58/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1519 - sparse_categorical_accuracy: 0.4904 - val_loss: 1.2518 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.005.
# Epoch 59/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1468 - sparse_categorical_accuracy: 0.4904 - val_loss: 1.2112 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.005.
# Epoch 60/500
# 22/22 [==============================] - 1s 36ms/step - loss: 1.1408 - sparse_categorical_accuracy: 0.4964 - val_loss: 1.2529 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.005.
# Epoch 61/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1410 - sparse_categorical_accuracy: 0.4900 - val_loss: 1.2077 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.005.
# Epoch 62/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1419 - sparse_categorical_accuracy: 0.4890 - val_loss: 1.2582 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.005.
# Epoch 63/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1332 - sparse_categorical_accuracy: 0.5153 - val_loss: 1.2368 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.005.
# Epoch 64/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1307 - sparse_categorical_accuracy: 0.4922 - val_loss: 1.2681 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.005.
# Epoch 65/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1354 - sparse_categorical_accuracy: 0.4907 - val_loss: 1.2426 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.005.
# Epoch 66/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1326 - sparse_categorical_accuracy: 0.5000 - val_loss: 1.2269 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.005.
# Epoch 67/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1230 - sparse_categorical_accuracy: 0.5146 - val_loss: 1.3142 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.005.
# Epoch 68/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1223 - sparse_categorical_accuracy: 0.5050 - val_loss: 1.2780 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.005.
# Epoch 69/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1292 - sparse_categorical_accuracy: 0.5021 - val_loss: 1.2193 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.005.
# Epoch 70/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1199 - sparse_categorical_accuracy: 0.5007 - val_loss: 1.2360 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.005.
# Epoch 71/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1204 - sparse_categorical_accuracy: 0.5068 - val_loss: 1.2227 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.005.
# Epoch 72/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1266 - sparse_categorical_accuracy: 0.5096 - val_loss: 1.2523 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.005.
# Epoch 73/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1216 - sparse_categorical_accuracy: 0.5018 - val_loss: 1.1873 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.005.
# Epoch 74/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1145 - sparse_categorical_accuracy: 0.5011 - val_loss: 1.2114 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.005.
# Epoch 75/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1126 - sparse_categorical_accuracy: 0.5050 - val_loss: 1.2968 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.005.
# Epoch 76/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1109 - sparse_categorical_accuracy: 0.5057 - val_loss: 1.2733 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.005.
# Epoch 77/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1027 - sparse_categorical_accuracy: 0.5110 - val_loss: 1.2679 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.005.
# Epoch 78/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1041 - sparse_categorical_accuracy: 0.5199 - val_loss: 1.2702 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.005.
# Epoch 79/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.1024 - sparse_categorical_accuracy: 0.5089 - val_loss: 1.3557 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0050
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.005.
# Epoch 80/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0954 - sparse_categorical_accuracy: 0.5135 - val_loss: 1.1923 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.005.
# Epoch 81/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.1016 - sparse_categorical_accuracy: 0.5011 - val_loss: 1.4156 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0050
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.005.
# Epoch 82/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.0994 - sparse_categorical_accuracy: 0.5164 - val_loss: 1.3052 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0050
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.005.
# Epoch 83/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.0927 - sparse_categorical_accuracy: 0.5089 - val_loss: 1.2369 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.005.
# Epoch 84/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0862 - sparse_categorical_accuracy: 0.5271 - val_loss: 1.2462 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.005.
# Epoch 85/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0820 - sparse_categorical_accuracy: 0.5224 - val_loss: 1.2382 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.005.
# Epoch 86/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0947 - sparse_categorical_accuracy: 0.5021 - val_loss: 1.2771 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.005.
# Epoch 87/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0797 - sparse_categorical_accuracy: 0.5146 - val_loss: 1.4170 - val_sparse_categorical_accuracy: 0.2414 - lr: 0.0050
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.005.
# Epoch 88/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0799 - sparse_categorical_accuracy: 0.5296 - val_loss: 1.2768 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.005.
# Epoch 89/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0683 - sparse_categorical_accuracy: 0.5381 - val_loss: 1.3664 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.005.
# Epoch 90/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0743 - sparse_categorical_accuracy: 0.5164 - val_loss: 1.3483 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.005.
# Epoch 91/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0698 - sparse_categorical_accuracy: 0.5246 - val_loss: 1.3375 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.005.
# Epoch 92/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0613 - sparse_categorical_accuracy: 0.5221 - val_loss: 1.2937 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.005.
# Epoch 93/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0701 - sparse_categorical_accuracy: 0.5249 - val_loss: 1.2731 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.005.
# Epoch 94/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0600 - sparse_categorical_accuracy: 0.5274 - val_loss: 1.4202 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.005.
# Epoch 95/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.0559 - sparse_categorical_accuracy: 0.5356 - val_loss: 1.2225 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.005.
# Epoch 96/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.0550 - sparse_categorical_accuracy: 0.5299 - val_loss: 1.3154 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.005.
# Epoch 97/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0296 - sparse_categorical_accuracy: 0.5563 - val_loss: 1.3737 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.005.
# Epoch 98/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.0387 - sparse_categorical_accuracy: 0.5434 - val_loss: 1.4493 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0050
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.005.
# Epoch 99/500
# 22/22 [==============================] - 1s 34ms/step - loss: 1.0414 - sparse_categorical_accuracy: 0.5474 - val_loss: 1.4059 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0050
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.005.
# Epoch 100/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0266 - sparse_categorical_accuracy: 0.5363 - val_loss: 1.3330 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.005.
# Epoch 101/500
# 22/22 [==============================] - 1s 33ms/step - loss: 1.0337 - sparse_categorical_accuracy: 0.5424 - val_loss: 1.2340 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.002.
# Epoch 102/500
# 22/22 [==============================] - 1s 33ms/step - loss: 0.9967 - sparse_categorical_accuracy: 0.5616 - val_loss: 1.3572 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.002.
# Epoch 103/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9785 - sparse_categorical_accuracy: 0.5548 - val_loss: 1.3252 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.002.
# Epoch 104/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9792 - sparse_categorical_accuracy: 0.5680 - val_loss: 1.3440 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.002.
# Epoch 105/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9612 - sparse_categorical_accuracy: 0.5780 - val_loss: 1.3745 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.002.
# Epoch 106/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9538 - sparse_categorical_accuracy: 0.5830 - val_loss: 1.2670 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.002.
# Epoch 107/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9518 - sparse_categorical_accuracy: 0.5787 - val_loss: 1.4204 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.002.
# Epoch 108/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9474 - sparse_categorical_accuracy: 0.5816 - val_loss: 1.2790 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.002.
# Epoch 109/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9477 - sparse_categorical_accuracy: 0.5776 - val_loss: 1.3273 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.002.
# Epoch 110/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9467 - sparse_categorical_accuracy: 0.5791 - val_loss: 1.3348 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.002.
# Epoch 111/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9283 - sparse_categorical_accuracy: 0.5983 - val_loss: 1.4017 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.002.
# Epoch 112/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9339 - sparse_categorical_accuracy: 0.5979 - val_loss: 1.3558 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.002.
# Epoch 113/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9354 - sparse_categorical_accuracy: 0.5951 - val_loss: 1.3224 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.002.
# Epoch 114/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9201 - sparse_categorical_accuracy: 0.5951 - val_loss: 1.2683 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0020
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.002.
# Epoch 115/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9276 - sparse_categorical_accuracy: 0.5915 - val_loss: 1.4118 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.002.
# Epoch 116/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9170 - sparse_categorical_accuracy: 0.5969 - val_loss: 1.3483 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.002.
# Epoch 117/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9232 - sparse_categorical_accuracy: 0.5954 - val_loss: 1.3444 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.002.
# Epoch 118/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.9048 - sparse_categorical_accuracy: 0.6001 - val_loss: 1.4861 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.002.
# Epoch 119/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9042 - sparse_categorical_accuracy: 0.6061 - val_loss: 1.2484 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.002.
# Epoch 120/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8787 - sparse_categorical_accuracy: 0.6154 - val_loss: 1.4073 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.002.
# Epoch 121/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8950 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.3557 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0020
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.002.
# Epoch 122/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8927 - sparse_categorical_accuracy: 0.6090 - val_loss: 1.4311 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.002.
# Epoch 123/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8793 - sparse_categorical_accuracy: 0.6111 - val_loss: 1.4357 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0020
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.002.
# Epoch 124/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8871 - sparse_categorical_accuracy: 0.6022 - val_loss: 1.4119 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.002.
# Epoch 125/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8781 - sparse_categorical_accuracy: 0.6154 - val_loss: 1.3952 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0020
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.002.
# Epoch 126/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8669 - sparse_categorical_accuracy: 0.6246 - val_loss: 1.4460 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.002.
# Epoch 127/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8626 - sparse_categorical_accuracy: 0.6225 - val_loss: 1.4378 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.002.
# Epoch 128/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8630 - sparse_categorical_accuracy: 0.6161 - val_loss: 1.5738 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.002.
# Epoch 129/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8530 - sparse_categorical_accuracy: 0.6332 - val_loss: 1.5604 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.002.
# Epoch 130/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8456 - sparse_categorical_accuracy: 0.6236 - val_loss: 1.6178 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.002.
# Epoch 131/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8440 - sparse_categorical_accuracy: 0.6343 - val_loss: 1.5550 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.002.
# Epoch 132/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8393 - sparse_categorical_accuracy: 0.6296 - val_loss: 1.4085 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.002.
# Epoch 133/500
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8464 - sparse_categorical_accuracy: 0.6339 - val_loss: 1.4237 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.002.
# Epoch 134/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.8238 - sparse_categorical_accuracy: 0.6496 - val_loss: 1.4120 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.002.
# Epoch 135/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8193 - sparse_categorical_accuracy: 0.6478 - val_loss: 1.4335 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.002.
# Epoch 136/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8134 - sparse_categorical_accuracy: 0.6474 - val_loss: 1.4534 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.002.
# Epoch 137/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8071 - sparse_categorical_accuracy: 0.6510 - val_loss: 1.4712 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.002.
# Epoch 138/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8040 - sparse_categorical_accuracy: 0.6578 - val_loss: 1.5029 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0020
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.002.
# Epoch 139/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8068 - sparse_categorical_accuracy: 0.6474 - val_loss: 1.4879 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.002.
# Epoch 140/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7926 - sparse_categorical_accuracy: 0.6563 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0020
#
# Epoch 141: LearningRateScheduler setting learning rate to 0.002.
# Epoch 141/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7832 - sparse_categorical_accuracy: 0.6546 - val_loss: 1.5798 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.002.
# Epoch 142/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7810 - sparse_categorical_accuracy: 0.6706 - val_loss: 1.6322 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.002.
# Epoch 143/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7690 - sparse_categorical_accuracy: 0.6624 - val_loss: 1.6055 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.002.
# Epoch 144/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7688 - sparse_categorical_accuracy: 0.6638 - val_loss: 1.6000 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0020
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.002.
# Epoch 145/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7773 - sparse_categorical_accuracy: 0.6642 - val_loss: 1.6057 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.002.
# Epoch 146/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7701 - sparse_categorical_accuracy: 0.6581 - val_loss: 1.9349 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.002.
# Epoch 147/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7593 - sparse_categorical_accuracy: 0.6684 - val_loss: 1.5217 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0020
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.002.
# Epoch 148/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7477 - sparse_categorical_accuracy: 0.6798 - val_loss: 1.5578 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.002.
# Epoch 149/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7424 - sparse_categorical_accuracy: 0.6763 - val_loss: 1.6562 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.002.
# Epoch 150/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7169 - sparse_categorical_accuracy: 0.6934 - val_loss: 1.7262 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.002.
# Epoch 151/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7275 - sparse_categorical_accuracy: 0.6866 - val_loss: 1.6987 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.001.
# Epoch 152/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6989 - sparse_categorical_accuracy: 0.7019 - val_loss: 1.5032 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0010
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.001.
# Epoch 153/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6943 - sparse_categorical_accuracy: 0.7005 - val_loss: 1.5292 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.001.
# Epoch 154/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6794 - sparse_categorical_accuracy: 0.7108 - val_loss: 1.6477 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.001.
# Epoch 155/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6549 - sparse_categorical_accuracy: 0.7098 - val_loss: 1.6953 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.001.
# Epoch 156/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6722 - sparse_categorical_accuracy: 0.7066 - val_loss: 1.7543 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.001.
# Epoch 157/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6489 - sparse_categorical_accuracy: 0.7343 - val_loss: 1.6696 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.001.
# Epoch 158/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.6513 - sparse_categorical_accuracy: 0.7304 - val_loss: 1.6687 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.001.
# Epoch 159/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6532 - sparse_categorical_accuracy: 0.7236 - val_loss: 1.6636 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.001.
# Epoch 160/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6649 - sparse_categorical_accuracy: 0.7165 - val_loss: 1.7896 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.001.
# Epoch 161/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6282 - sparse_categorical_accuracy: 0.7333 - val_loss: 1.6676 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.001.
# Epoch 162/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6344 - sparse_categorical_accuracy: 0.7365 - val_loss: 1.7899 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.001.
# Epoch 163/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6292 - sparse_categorical_accuracy: 0.7333 - val_loss: 1.6630 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.001.
# Epoch 164/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6392 - sparse_categorical_accuracy: 0.7365 - val_loss: 1.7289 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.001.
# Epoch 165/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.6198 - sparse_categorical_accuracy: 0.7407 - val_loss: 1.8872 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.001.
# Epoch 166/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.6147 - sparse_categorical_accuracy: 0.7382 - val_loss: 1.8188 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0010
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.001.
# Epoch 167/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.5930 - sparse_categorical_accuracy: 0.7532 - val_loss: 1.8406 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0010
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.001.
# Epoch 168/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5906 - sparse_categorical_accuracy: 0.7493 - val_loss: 1.8299 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0010
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.001.
# Epoch 169/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5897 - sparse_categorical_accuracy: 0.7621 - val_loss: 1.7121 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.001.
# Epoch 170/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5868 - sparse_categorical_accuracy: 0.7561 - val_loss: 1.8786 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.001.
# Epoch 171/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5846 - sparse_categorical_accuracy: 0.7653 - val_loss: 1.9133 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.001.
# Epoch 172/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.5784 - sparse_categorical_accuracy: 0.7528 - val_loss: 1.9394 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.001.
# Epoch 173/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5827 - sparse_categorical_accuracy: 0.7507 - val_loss: 1.8653 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0010
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.001.
# Epoch 174/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5760 - sparse_categorical_accuracy: 0.7561 - val_loss: 1.9165 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.001.
# Epoch 175/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5662 - sparse_categorical_accuracy: 0.7692 - val_loss: 1.8179 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.001.
# Epoch 176/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5640 - sparse_categorical_accuracy: 0.7575 - val_loss: 1.7863 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.001.
# Epoch 177/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5709 - sparse_categorical_accuracy: 0.7564 - val_loss: 2.1191 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.001.
# Epoch 178/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5520 - sparse_categorical_accuracy: 0.7724 - val_loss: 1.9844 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.001.
# Epoch 179/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.5575 - sparse_categorical_accuracy: 0.7703 - val_loss: 1.9150 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0010
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.001.
# Epoch 180/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5502 - sparse_categorical_accuracy: 0.7699 - val_loss: 1.9414 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0010
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.001.
# Epoch 181/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5558 - sparse_categorical_accuracy: 0.7678 - val_loss: 1.8480 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0010
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.001.
# Epoch 182/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5418 - sparse_categorical_accuracy: 0.7749 - val_loss: 2.0084 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.001.
# Epoch 183/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5377 - sparse_categorical_accuracy: 0.7724 - val_loss: 1.9179 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 184: LearningRateScheduler setting learning rate to 0.001.
# Epoch 184/500
# ...
#
# Epoch 441: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 441/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1606 - sparse_categorical_accuracy: 0.9420 - val_loss: 3.0542 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 442: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 442/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9541 - val_loss: 3.0627 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 443: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 443/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1694 - sparse_categorical_accuracy: 0.9391 - val_loss: 3.0746 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 444: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 444/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1609 - sparse_categorical_accuracy: 0.9448 - val_loss: 3.0585 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 445: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 445/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1585 - sparse_categorical_accuracy: 0.9476 - val_loss: 3.0698 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 446: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 446/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1437 - sparse_categorical_accuracy: 0.9516 - val_loss: 3.0550 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 447: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 447/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1606 - sparse_categorical_accuracy: 0.9441 - val_loss: 3.0553 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 448: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 448/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1601 - sparse_categorical_accuracy: 0.9405 - val_loss: 3.0633 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 449: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 449/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1705 - sparse_categorical_accuracy: 0.9366 - val_loss: 3.0330 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 450: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 450/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9466 - val_loss: 2.9925 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 451: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 451/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1536 - sparse_categorical_accuracy: 0.9487 - val_loss: 3.0492 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 452: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 452/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1574 - sparse_categorical_accuracy: 0.9462 - val_loss: 3.0991 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 453: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 453/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9512 - val_loss: 3.0926 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 454: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 454/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1520 - sparse_categorical_accuracy: 0.9491 - val_loss: 3.0653 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 455: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 455/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1384 - sparse_categorical_accuracy: 0.9583 - val_loss: 3.0741 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 456: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 456/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1549 - sparse_categorical_accuracy: 0.9473 - val_loss: 3.0892 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 457: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 457/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.1569 - sparse_categorical_accuracy: 0.9480 - val_loss: 3.0921 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 458: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 458/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1414 - sparse_categorical_accuracy: 0.9573 - val_loss: 3.0584 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 459: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 459/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1350 - sparse_categorical_accuracy: 0.9576 - val_loss: 3.0408 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 460: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 460/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1415 - sparse_categorical_accuracy: 0.9548 - val_loss: 3.1082 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 461: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 461/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1503 - sparse_categorical_accuracy: 0.9473 - val_loss: 3.0986 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 462: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 462/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1532 - sparse_categorical_accuracy: 0.9491 - val_loss: 3.1018 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 463: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 463/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1440 - sparse_categorical_accuracy: 0.9494 - val_loss: 3.1556 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 464: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 464/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1482 - sparse_categorical_accuracy: 0.9537 - val_loss: 3.1007 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 465: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 465/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9512 - val_loss: 3.0931 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 466: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 466/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1637 - sparse_categorical_accuracy: 0.9402 - val_loss: 3.0303 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 467: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 467/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1395 - sparse_categorical_accuracy: 0.9551 - val_loss: 3.0184 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 468: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 468/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1470 - sparse_categorical_accuracy: 0.9498 - val_loss: 3.0145 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 469: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 469/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1472 - sparse_categorical_accuracy: 0.9523 - val_loss: 3.0497 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 470: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 470/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1469 - sparse_categorical_accuracy: 0.9544 - val_loss: 3.0612 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 471: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 471/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1433 - sparse_categorical_accuracy: 0.9505 - val_loss: 3.0809 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 472: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 472/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9569 - val_loss: 3.1112 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 473: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 473/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1465 - sparse_categorical_accuracy: 0.9519 - val_loss: 3.1147 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 474: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 474/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1324 - sparse_categorical_accuracy: 0.9619 - val_loss: 3.1213 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 475: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 475/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1333 - sparse_categorical_accuracy: 0.9562 - val_loss: 3.1467 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 476: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 476/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1472 - sparse_categorical_accuracy: 0.9551 - val_loss: 3.1215 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 477: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 477/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1398 - sparse_categorical_accuracy: 0.9501 - val_loss: 3.1403 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 478: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 478/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1433 - sparse_categorical_accuracy: 0.9544 - val_loss: 3.1452 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 479: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 479/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1280 - sparse_categorical_accuracy: 0.9623 - val_loss: 3.0860 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 480: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 480/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1418 - sparse_categorical_accuracy: 0.9505 - val_loss: 3.0793 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 481: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 481/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1460 - sparse_categorical_accuracy: 0.9501 - val_loss: 3.1204 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 482: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 482/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1447 - sparse_categorical_accuracy: 0.9505 - val_loss: 3.1416 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 483: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 483/500
# 22/22 [==============================] - 1s 37ms/step - loss: 0.1366 - sparse_categorical_accuracy: 0.9512 - val_loss: 3.0995 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 484: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 484/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1442 - sparse_categorical_accuracy: 0.9516 - val_loss: 3.0859 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 485: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 485/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1402 - sparse_categorical_accuracy: 0.9576 - val_loss: 3.0731 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 486: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 486/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1447 - sparse_categorical_accuracy: 0.9523 - val_loss: 3.1002 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 487: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 487/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1401 - sparse_categorical_accuracy: 0.9530 - val_loss: 3.0902 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 488: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 488/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1500 - sparse_categorical_accuracy: 0.9459 - val_loss: 3.1053 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 489: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 489/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1369 - sparse_categorical_accuracy: 0.9580 - val_loss: 3.1161 - val_sparse_categorical_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 490: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 490/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1392 - sparse_categorical_accuracy: 0.9544 - val_loss: 3.1177 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 491: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 491/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1519 - sparse_categorical_accuracy: 0.9437 - val_loss: 3.1211 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 492: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 492/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1527 - sparse_categorical_accuracy: 0.9430 - val_loss: 3.1360 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 493: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 493/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1573 - sparse_categorical_accuracy: 0.9448 - val_loss: 3.1348 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 494: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 494/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1489 - sparse_categorical_accuracy: 0.9505 - val_loss: 3.1106 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 495: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 495/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1354 - sparse_categorical_accuracy: 0.9566 - val_loss: 3.0633 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 496: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 496/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1454 - sparse_categorical_accuracy: 0.9491 - val_loss: 3.1043 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 497: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 497/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1412 - sparse_categorical_accuracy: 0.9519 - val_loss: 3.1201 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 498: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 498/500
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1420 - sparse_categorical_accuracy: 0.9573 - val_loss: 3.0968 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 499: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 499/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1366 - sparse_categorical_accuracy: 0.9551 - val_loss: 3.1055 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04
#
# Epoch 500: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 500/500
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1427 - sparse_categorical_accuracy: 0.9512 - val_loss: 3.0934 - val_sparse_categorical_accuracy: 0.5517 - lr: 1.0000e-04

# %%
train_acc = history.history['sparse_categorical_accuracy']
train_loss = history.history['loss']

val_acc = history.history['val_sparse_categorical_accuracy']
val_loss = history.history['val_loss']

plt.figure()
plt.plot(range(epoch), train_loss, label='train_loss')
plt.plot(range(epoch), val_loss, label='val_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

plt.figure()
plt.plot(range(epoch), train_acc, label='train_acc')
plt.plot(range(epoch), val_acc, label='val_acc')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('msle')
plt.show()

# %%
model.evaluate(test_ds)

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)

df_time = date[-len(y_test):]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, y_test, 'b-', label='actual')
axes.plot(df_time, y_pred, 'r--', label='predict')
print(y_pred)
axes.set_xticks(df_time[::1])
axes.set_xticklabels(df_time[::1],rotation=45)

plt.legend()
plt.grid()
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step - loss: 3.0934 - sparse_categorical_accuracy: 0.5517
# 1/1 [==============================] - 0s 183ms/step
# 2023-07-21 13:23:35.910517: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [4 5 5 5 5 3 4 4 4 4 3 4 5 4 4 4 4 5 5 5 2 5 5 4 5 5 4 4 5]

# %%
price_actual = list()
price_pred = list()
price_actual.append(1.0)
price_pred.append(1.0)
    

for idx in range(1, len(y_test)):
    price_actual.append(price_actual[idx-1] * change_test[idx])
    price_pred.append(price_pred[idx-1] * label2change(y_pred[idx]))
print(price_actual)
print(price_pred)
# Out:
# [1.0, 1.0021977424621582, 0.9978021550964513, 1.0703295490642146, 1.0659339624585153, 1.0439559413040178, 1.0417581053935308, 1.054945052045385, 1.0417581257114925, 1.024175695415759, 0.980219668513828, 1.0197800233944425, 1.0835162748565952, 1.0593405525378703, 1.0923075486453682, 1.0923075486453682, 1.0791207269749712, 1.109890033315542, 1.1230768945862628, 1.1010988900646868, 1.0901098322880776, 1.1670328967470367, 1.2065932513953992, 1.1450548391680666, 1.2175822808848387, 1.3054944071347725, 1.2043954890251036, 1.2879119938852652, 1.417582189377483]
# [1.0, 1.1, 1.2100000000000002, 1.3310000000000004, 1.4641000000000006, 1.4201770000000005, 1.4059752300000004, 1.3919154777000002, 1.3779963229230001, 1.3642163596937702, 1.323289868902957, 1.3100569702139275, 1.4410626672353204, 1.4266520405629672, 1.4123855201573376, 1.3982616649557642, 1.3842790483062066, 1.5227069531368274, 1.6749776484505103, 1.8424754132955614, 1.7503516426307832, 1.9253868068938618, 2.117925487583248, 2.0967462327074156, 2.3064208559781574, 2.5370629415759733, 2.5116923121602137, 2.4865753890386117, 2.735232927942473]

# %%
df_time = date[-len(y_test):]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, price_actual, 'b-', label='actual')
axes.plot(df_time, price_pred, 'r--', label='predict')

axes.set_xticks(df_time[::1])
axes.set_xticklabels(df_time[::1],rotation=45)

plt.legend()
plt.grid()
plt.show()

# %%
actual_profit_rate = 1
for idx in range(0, len(y_pred)):
    if y_pred[idx] >= 1:
        actual_profit_rate *= change_test[idx]
print(actual_profit_rate)
# Out:
# 1.4052285045252226

# %%
predict_train = model.predict(x_train)
predict_train = np.argmax(predict_train, axis=1)

df_time = date[mem_his_days + pre_days - 1 :mem_his_days + pre_days - 1 + len(predict_train)]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, y_train, 'b-', label='actual')
print(predict_train.shape)
axes.plot(df_time, predict_train, 'r--', label='predict')

axes.set_xticks(df_time[::100])
axes.set_xticklabels(df_time[::100],rotation=45)

plt.legend()
plt.grid()
plt.show()
# Out:
# 88/88 [==============================] - 1s 10ms/step
# (2808,)

# %%
predict_x = np.array(predict_x).reshape(-1,num_feature * mem_his_days,1)
predict = model.predict(predict_x)
predict = np.argmax(predict, axis=1)

def up_or_down(pred):
    if pred >= 3:
        return '↗'
    return '↘'
print('Current code is ' + stock_code + ', current date is ' + newest_data)
print('T+1 ' + up_or_down(predict[0]))
print('T+2 ' + up_or_down(predict[1]))
# Out:
# 1/1 [==============================] - 0s 153ms/step
# Current code is 002316, current date is 2023-07-20
# T+1 ↗
# T+2 ↗
