# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import happybase
import collections
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.9.2
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
pre_days = 7
mem_his_days = 17
epoch = 500
train_rate = 0.99
table_name = 'certificate'
column_family = 'feature'
stock_code = '002316'

# %%
def change2label(x):
    if x < 0.92:
       return 0
    elif x < 0.94:
       return 1
    elif x < 0.96:
       return 2
    elif x < 0.98:
       return 3
    elif x < 1.:
       return 4
    elif x < 1.2:
       return 5
    elif x < 1.4:
       return 6
    elif x < 1.6:
       return 7
    elif x < 1.8:
       return 8
    return 9

def label2change(label):
    if label == 0:
        return 0.91
    elif label == 1:
        return 0.93
    elif label == 2:
        return 0.95
    elif label == 3:
        return 0.97
    elif label == 4:
        return 0.99
    elif label == 5:
        return 1.1
    elif label == 6:
        return 1.3
    elif label == 7:
        return 1.5
    elif label == 8:
        return 1.7
    return 1.9

# %%
# load features from hbase
connection = happybase.Connection('localhost', 9090, transport='framed', protocol='compact')
connection.open()
table = connection.table(table_name)
rows = table.scan(row_prefix=stock_code.encode('utf-8'))
df = pd.DataFrame()
idx = int(0)
newest_data = '1970-01-01'
for row in rows:
    date = row[0].decode('utf-8').split('_')[-1]
    cells = row[1]
    for column in cells:
        df.at[idx, column.decode('utf-8').split(':')[-1]] = np.float32(cells[column].decode('utf-8'))
    df.at[idx, 'date'] = date
    newest_data = max(date, newest_data)
    
    idx = idx + 1
connection.close()
df.dropna(inplace=True)
df
# Out:
#       macd_dea  macd_diff  macd_ema12  macd_ema26  macd_macd  trade_c  \
# 8       -0.130     -0.836   34.603001   35.439400     -1.412    31.18
# 9       -0.352     -1.241   33.704102   34.944599     -1.776    28.76
# 10      -0.561     -1.397   33.224998   34.622002     -1.672    30.59
# 11      -0.737     -1.439   32.944199   34.383301     -1.405    31.40
# 12      -0.891     -1.508   32.605099   34.113400     -1.234    30.74
# ...        ...        ...         ...         ...        ...      ...
# 2852     0.113      0.165    5.015800    4.851300      0.104     5.54
# 2853     0.129      0.196    5.099500    4.903800      0.133     5.56
# 2854     0.143      0.200    5.135000    4.935400      0.113     5.33
# 2855     0.163      0.243    5.246500    5.003900      0.159     5.86
# 2856     0.195      0.321    5.431700    5.111000      0.252     6.45
#
#           trade_e    trade_h   trade_hs    trade_l    trade_o    trade_v  \
# 8      90117944.0  31.690001  12.060000  30.400000  30.469999    28941.0
# 9     114190072.0  31.080000  16.139999  28.600000  30.889999    38735.0
# 10    155427968.0  31.290001  21.440001  28.690001  28.690001    51455.0
# 11    152094352.0  31.799999  20.629999  29.389999  30.170000    49503.0
# 12     90032200.0  31.389999  12.130000  30.420000  30.500000    29106.0
# ...           ...        ...        ...        ...        ...        ...
# 2852  212349872.0   5.540000  12.510000   5.010000   5.010000   394061.0
# 2853  599063808.0   5.940000  33.700001   5.400000   5.540000  1061622.0
# 2854  313424032.0   5.480000  18.760000   5.200000   5.410000   591018.0
# 2855  271282048.0   5.860000  14.860000   5.230000   5.250000   468242.0
# 2856   70665760.0   6.450000   3.480000   6.450000   6.450000   109559.0
#
#       trade_zd  trade_zde  trade_zf        date      kdj_d       kdj_j  \
# 8         1.53       0.47      4.20  2009-12-21   8.500000    8.500000
# 9        -7.76      -2.42      7.95  2009-12-22   7.680000    2.790000
# 10        6.36       1.83      9.04  2009-12-23   8.030000   10.130000
# 11        2.65       0.81      7.88  2009-12-24   9.880000   20.980000
# 12       -2.10      -0.66      3.09  2009-12-25  12.130000   25.660000
# ...        ...        ...       ...         ...        ...         ...
# 2852      9.92       0.50     10.52  2023-07-14  65.970001   74.309998
# 2853      0.36       0.02      9.75  2023-07-17  66.760002   71.500000
# 2854     -4.14      -0.23      5.04  2023-07-18  65.019997   54.520000
# 2855      9.94       0.53     11.82  2023-07-19  67.360001   81.459999
# 2856     10.07       0.59      0.00  2023-07-20  72.019997  100.040001
#
#           kdj_k
# 8      8.500000
# 9      6.050000
# 10     8.730000
# 11    13.580000
# 12    16.639999
# ...         ...
# 2852  68.750000
# 2853  68.339996
# 2854  61.520000
# 2855  72.059998
# 2856  81.360001
#
# [2849 rows x 19 columns]

# %%
df['PreHigh'] = df['trade_h'].shift(1)
df["Change"] = df['trade_h'] / df['PreHigh']

df = df.dropna()
change = np.array(df['Change']).astype(np.float32)
df['Change'] = df['Change'].apply(change2label)

df = df.drop('trade_h', axis=1)
df = df.drop('PreHigh', axis=1)

date = df['date']
df = df.drop(labels='date', axis=1)

scaler = MinMaxScaler((0, 1))

sca = scaler.fit_transform(df.iloc[:, :-1])
print(scaler.data_max_, scaler.data_min_)
label = np.array(df.iloc[:, -1])
print(sca)
print(label)
# Out:
# [2.06299996e+00 2.34999990e+00 3.37041016e+01 3.49445992e+01
#  1.86300004e+00 3.50800018e+01 1.73344512e+09 5.65800018e+01
#  3.36300011e+01 3.50000000e+01 1.66022800e+06 1.01199999e+01
#  2.24000001e+00 1.99500008e+01 9.65899963e+01 1.24339996e+02
#  9.90800018e+01] [-2.39299989e+00 -2.64299989e+00  2.29970002e+00  2.41529989e+00
#  -1.77600002e+00  2.24000001e+00  4.41216000e+05  5.00000007e-02
#   2.21000004e+00  2.22000003e+00  1.53200000e+03 -3.29399986e+01
#  -6.32000017e+00  0.00000000e+00  4.46000004e+00 -2.51299992e+01
#   1.70000005e+00]
# [[0.4580341  0.28079309 1.         ... 0.03495061 0.18679334 0.04467036]
#  [0.41113105 0.24954937 0.98474408 ... 0.03874959 0.23590018 0.07219141]
#  [0.37163374 0.24113758 0.97580266 ... 0.05882992 0.30849    0.1219963 ]
#  ...
#  [0.56912028 0.56939716 0.09028353 ... 0.65733202 0.53288287 0.61429451]
#  [0.57360861 0.57800921 0.09383398 ... 0.68273096 0.7131197  0.72253025]
#  [0.58078994 0.59363109 0.09973125 ... 0.73331162 0.8374256  0.81803244]]
# [4 5 5 ... 1 5 5]
# /var/folders/b1/0fd1b6hs7lz0fm_mh346lybm0000gn/T/ipykernel_72395/209548102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Change'] = df['Change'].apply(change2label)

# %%
deq = collections.deque()

x = []
for row in sca:
    deq.append(list(row))
    if len(deq) > mem_his_days:
        deq.popleft()
    if len(deq) == mem_his_days:
        x.append(list(deq))
predict_x = x[-pre_days:]
x = x[:-pre_days]
y = label[mem_his_days + pre_days - 1:]
change = change[mem_his_days + pre_days - 1:]

x, y = np.array(x).reshape(-1,mem_his_days,17,1), np.array(y)
print(x.shape)
print(y.shape)
# Out:
# (2825, 17, 17, 1)
# (2825,)

# %%
total_num = len(x)
train_num = int(total_num * train_rate)
print(train_num)
# Out:
# 2796

# %%
x_train, y_train, change_train = x[:train_num], y[:train_num], change[:train_num]
x_test, y_test, change_test = x[train_num:], y[train_num:], change[train_num:]

batch_size = 128

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.shuffle(train_num).batch(batch_size=batch_size).prefetch(tf.data.experimental.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_ds = test_ds.shuffle(total_num - train_num).batch(batch_size=batch_size).prefetch(tf.data.experimental.AUTOTUNE)

sample = next(iter(train_ds))
print('x_train.shape:', sample[0].shape)
print('y_train.shape:', sample[1].shape)
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# x_train.shape: (128, 17, 17, 1)
# y_train.shape: (128,)
# 2023-07-21 12:27:30.929393: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-21 12:27:30.929520: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
input_shape = sample[0].shape[-3:]

model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32,17,input_shape=input_shape,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Conv2D(64,17,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Conv2D(128,17,padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(tf.keras.layers.Dense(64))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dense(10,activation='softmax'))
model.build(input_shape=[None,mem_his_days,17])

model.summary()
# Out:
# (17, 17, 1)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 17, 17, 32)        9280
#
#  batch_normalization_4 (Batc  (None, 17, 17, 32)       128
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 17, 17, 32)        0
#
#  dropout_3 (Dropout)         (None, 17, 17, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          591936
#
#  batch_normalization_5 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 8, 8, 64)          0
#
#  dropout_4 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 128)         2367616
#
#  batch_normalization_6 (Batc  (None, 4, 4, 128)        512
#  hNormalization)
#
#  re_lu_6 (ReLU)              (None, 4, 4, 128)         0
#
#  dropout_5 (Dropout)         (None, 4, 4, 128)         0
#
#  global_average_pooling2d_1   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  re_lu_7 (ReLU)              (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 2,978,890
# Trainable params: 2,978,314
# Non-trainable params: 576
# _________________________________________________________________

# %%
# lr = tf.keras.optimizers.schedules.ExponentialDecay(0.01, decay_steps=20, decay_rate=0.8, staircase=False)
optimizer = tf.keras.optimizers.Adam()
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = tf.keras.metrics.SparseCategoricalAccuracy()

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=[metrics])

# model.compile(optimizer=tf.keras.optimizers.RMSprop(),
#               loss=tf.keras.losses.MeanAbsoluteError(),
#               metrics=tf.keras.losses.MeanSquaredLogarithmicError())

def lr_schedule(epoch):
    if epoch > 350:
        return 0.0001
    if epoch > 200:
        return 0.0005
    if epoch > 150:
        return 0.001
    if epoch > 100:
        return 0.002
    if epoch > 50:
        return 0.005
    return 0.01
        
lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_schedule,verbose=True)

history = model.fit(train_ds,
                    epochs=epoch,
                    validation_data=test_ds,
                    callbacks=[lr_callback])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/500
# 2023-07-21 12:27:31.588317: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-07-21 12:27:31.588496: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 2s 58ms/step - loss: 1.5219 - sparse_categorical_accuracy: 0.4199 - val_loss: 4.5061 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/500
#  1/22 [>.............................] - ETA: 1s - loss: 1.2773 - sparse_categorical_accuracy: 0.5156
# 2023-07-21 12:27:33.239479: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2669 - sparse_categorical_accuracy: 0.4614 - val_loss: 2.8801 - val_sparse_categorical_accuracy: 0.0690 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2425 - sparse_categorical_accuracy: 0.4621 - val_loss: 1.3728 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2370 - sparse_categorical_accuracy: 0.4539 - val_loss: 1.3008 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2306 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.4057 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2394 - sparse_categorical_accuracy: 0.4635 - val_loss: 1.3810 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2280 - sparse_categorical_accuracy: 0.4664 - val_loss: 1.3909 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.01.
# Epoch 8/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2354 - sparse_categorical_accuracy: 0.4639 - val_loss: 1.2944 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.01.
# Epoch 9/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2290 - sparse_categorical_accuracy: 0.4603 - val_loss: 1.2558 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.01.
# Epoch 10/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2223 - sparse_categorical_accuracy: 0.4657 - val_loss: 1.2434 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.01.
# Epoch 11/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2232 - sparse_categorical_accuracy: 0.4696 - val_loss: 1.2429 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.01.
# Epoch 12/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2175 - sparse_categorical_accuracy: 0.4707 - val_loss: 1.2183 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.01.
# Epoch 13/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2213 - sparse_categorical_accuracy: 0.4760 - val_loss: 1.1993 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.01.
# Epoch 14/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2281 - sparse_categorical_accuracy: 0.4721 - val_loss: 1.2283 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.01.
# Epoch 15/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2240 - sparse_categorical_accuracy: 0.4610 - val_loss: 1.2166 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.01.
# Epoch 16/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2262 - sparse_categorical_accuracy: 0.4649 - val_loss: 1.2343 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.01.
# Epoch 17/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2207 - sparse_categorical_accuracy: 0.4657 - val_loss: 1.2715 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.01.
# Epoch 18/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2194 - sparse_categorical_accuracy: 0.4646 - val_loss: 1.2250 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.01.
# Epoch 19/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2210 - sparse_categorical_accuracy: 0.4660 - val_loss: 1.2298 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.01.
# Epoch 20/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2264 - sparse_categorical_accuracy: 0.4700 - val_loss: 1.2202 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.01.
# Epoch 21/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2171 - sparse_categorical_accuracy: 0.4642 - val_loss: 1.2572 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.01.
# Epoch 22/500
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2190 - sparse_categorical_accuracy: 0.4714 - val_loss: 1.2610 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.01.
# Epoch 23/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2190 - sparse_categorical_accuracy: 0.4728 - val_loss: 1.2358 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.01.
# Epoch 24/500
# 22/22 [==============================] - 1s 41ms/step - loss: 1.2124 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.2170 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.01.
# Epoch 25/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2096 - sparse_categorical_accuracy: 0.4721 - val_loss: 1.2435 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.01.
# Epoch 26/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2133 - sparse_categorical_accuracy: 0.4710 - val_loss: 1.2386 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.01.
# Epoch 27/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2125 - sparse_categorical_accuracy: 0.4760 - val_loss: 1.2159 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.01.
# Epoch 28/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2030 - sparse_categorical_accuracy: 0.4796 - val_loss: 1.2612 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.01.
# Epoch 29/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2040 - sparse_categorical_accuracy: 0.4821 - val_loss: 1.2284 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.01.
# Epoch 30/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2091 - sparse_categorical_accuracy: 0.4750 - val_loss: 1.2402 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.01.
# Epoch 31/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2087 - sparse_categorical_accuracy: 0.4717 - val_loss: 1.2390 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.01.
# Epoch 32/500
# 22/22 [==============================] - 1s 41ms/step - loss: 1.2126 - sparse_categorical_accuracy: 0.4746 - val_loss: 1.2099 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.01.
# Epoch 33/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2024 - sparse_categorical_accuracy: 0.4768 - val_loss: 1.2372 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.01.
# Epoch 34/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2007 - sparse_categorical_accuracy: 0.4835 - val_loss: 1.2071 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.01.
# Epoch 35/500
# 22/22 [==============================] - 1s 40ms/step - loss: 1.2071 - sparse_categorical_accuracy: 0.4739 - val_loss: 1.2417 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.01.
# Epoch 36/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2078 - sparse_categorical_accuracy: 0.4810 - val_loss: 1.2787 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.01.
# Epoch 37/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2068 - sparse_categorical_accuracy: 0.4843 - val_loss: 1.2782 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.01.
# Epoch 38/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2004 - sparse_categorical_accuracy: 0.4775 - val_loss: 1.2168 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.01.
# Epoch 39/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.1991 - sparse_categorical_accuracy: 0.4835 - val_loss: 1.2276 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.01.
# Epoch 40/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2023 - sparse_categorical_accuracy: 0.4796 - val_loss: 1.2253 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.01.
# Epoch 41/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.1967 - sparse_categorical_accuracy: 0.4814 - val_loss: 1.2035 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.01.
# Epoch 42/500
# 22/22 [==============================] - 1s 40ms/step - loss: 1.1957 - sparse_categorical_accuracy: 0.4782 - val_loss: 1.2126 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.01.
# Epoch 43/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.2007 - sparse_categorical_accuracy: 0.4739 - val_loss: 1.2102 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.01.
# Epoch 44/500
# 22/22 [==============================] - 1s 41ms/step - loss: 1.1982 - sparse_categorical_accuracy: 0.4857 - val_loss: 1.2346 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.01.
# Epoch 45/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.1969 - sparse_categorical_accuracy: 0.4821 - val_loss: 1.2393 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.01.
# Epoch 46/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.2034 - sparse_categorical_accuracy: 0.4807 - val_loss: 1.2348 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0100
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.01.
# Epoch 47/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.1935 - sparse_categorical_accuracy: 0.4721 - val_loss: 1.2559 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.01.
# Epoch 48/500
# 22/22 [==============================] - 1s 40ms/step - loss: 1.1934 - sparse_categorical_accuracy: 0.4832 - val_loss: 1.2424 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.01.
# Epoch 49/500
# 22/22 [==============================] - 1s 40ms/step - loss: 1.1940 - sparse_categorical_accuracy: 0.4810 - val_loss: 1.2549 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.01.
# Epoch 50/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.1841 - sparse_categorical_accuracy: 0.4914 - val_loss: 1.2500 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.01.
# Epoch 51/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1885 - sparse_categorical_accuracy: 0.4875 - val_loss: 1.2272 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0100
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.005.
# Epoch 52/500
# 22/22 [==============================] - 1s 40ms/step - loss: 1.1848 - sparse_categorical_accuracy: 0.4850 - val_loss: 1.2174 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.005.
# Epoch 53/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.1744 - sparse_categorical_accuracy: 0.4896 - val_loss: 1.1881 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.005.
# Epoch 54/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1693 - sparse_categorical_accuracy: 0.4868 - val_loss: 1.2054 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.005.
# Epoch 55/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1744 - sparse_categorical_accuracy: 0.4954 - val_loss: 1.2137 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.005.
# Epoch 56/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1694 - sparse_categorical_accuracy: 0.4964 - val_loss: 1.2070 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.005.
# Epoch 57/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1680 - sparse_categorical_accuracy: 0.5014 - val_loss: 1.2127 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.005.
# Epoch 58/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1678 - sparse_categorical_accuracy: 0.4975 - val_loss: 1.2119 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.005.
# Epoch 59/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1675 - sparse_categorical_accuracy: 0.4882 - val_loss: 1.2258 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.005.
# Epoch 60/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1607 - sparse_categorical_accuracy: 0.5004 - val_loss: 1.2120 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.005.
# Epoch 61/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1594 - sparse_categorical_accuracy: 0.5025 - val_loss: 1.1997 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.005.
# Epoch 62/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1572 - sparse_categorical_accuracy: 0.4932 - val_loss: 1.2369 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.005.
# Epoch 63/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1509 - sparse_categorical_accuracy: 0.5018 - val_loss: 1.1970 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.005.
# Epoch 64/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1531 - sparse_categorical_accuracy: 0.5061 - val_loss: 1.2325 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.005.
# Epoch 65/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1481 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.2013 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.005.
# Epoch 66/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1535 - sparse_categorical_accuracy: 0.4911 - val_loss: 1.2357 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.005.
# Epoch 67/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1453 - sparse_categorical_accuracy: 0.5075 - val_loss: 1.2502 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.005.
# Epoch 68/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1458 - sparse_categorical_accuracy: 0.4979 - val_loss: 1.2821 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.005.
# Epoch 69/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1418 - sparse_categorical_accuracy: 0.5007 - val_loss: 1.2738 - val_sparse_categorical_accuracy: 0.6207 - lr: 0.0050
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.005.
# Epoch 70/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1477 - sparse_categorical_accuracy: 0.4961 - val_loss: 1.2168 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.005.
# Epoch 71/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1360 - sparse_categorical_accuracy: 0.5011 - val_loss: 1.4349 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0050
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.005.
# Epoch 72/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1328 - sparse_categorical_accuracy: 0.5089 - val_loss: 1.2482 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.005.
# Epoch 73/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1329 - sparse_categorical_accuracy: 0.5093 - val_loss: 1.2348 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0050
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.005.
# Epoch 74/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1330 - sparse_categorical_accuracy: 0.5136 - val_loss: 1.3721 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.005.
# Epoch 75/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1291 - sparse_categorical_accuracy: 0.5021 - val_loss: 1.2395 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.005.
# Epoch 76/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1186 - sparse_categorical_accuracy: 0.5100 - val_loss: 1.1903 - val_sparse_categorical_accuracy: 0.5517 - lr: 0.0050
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.005.
# Epoch 77/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1244 - sparse_categorical_accuracy: 0.5172 - val_loss: 1.2168 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.005.
# Epoch 78/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1214 - sparse_categorical_accuracy: 0.5165 - val_loss: 1.2715 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.005.
# Epoch 79/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1159 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.2481 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.005.
# Epoch 80/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1075 - sparse_categorical_accuracy: 0.5154 - val_loss: 1.1851 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.005.
# Epoch 81/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1010 - sparse_categorical_accuracy: 0.5250 - val_loss: 1.1602 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.005.
# Epoch 82/500
# 22/22 [==============================] - 1s 40ms/step - loss: 1.0920 - sparse_categorical_accuracy: 0.5240 - val_loss: 1.1939 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.005.
# Epoch 83/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0930 - sparse_categorical_accuracy: 0.5240 - val_loss: 1.3564 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.005.
# Epoch 84/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.1028 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.3448 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.005.
# Epoch 85/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0844 - sparse_categorical_accuracy: 0.5186 - val_loss: 1.1603 - val_sparse_categorical_accuracy: 0.5862 - lr: 0.0050
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.005.
# Epoch 86/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0836 - sparse_categorical_accuracy: 0.5240 - val_loss: 1.2675 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.005.
# Epoch 87/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.0816 - sparse_categorical_accuracy: 0.5279 - val_loss: 1.3098 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.005.
# Epoch 88/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0728 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.2877 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.005.
# Epoch 89/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0753 - sparse_categorical_accuracy: 0.5358 - val_loss: 1.1937 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.005.
# Epoch 90/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0679 - sparse_categorical_accuracy: 0.5261 - val_loss: 1.2993 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.005.
# Epoch 91/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0697 - sparse_categorical_accuracy: 0.5268 - val_loss: 1.2438 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.005.
# Epoch 92/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0767 - sparse_categorical_accuracy: 0.5222 - val_loss: 1.3509 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.005.
# Epoch 93/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0558 - sparse_categorical_accuracy: 0.5222 - val_loss: 1.3375 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.005.
# Epoch 94/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0589 - sparse_categorical_accuracy: 0.5243 - val_loss: 1.1693 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0050
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.005.
# Epoch 95/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0497 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.2512 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0050
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.005.
# Epoch 96/500
# 22/22 [==============================] - 1s 39ms/step - loss: 1.0391 - sparse_categorical_accuracy: 0.5347 - val_loss: 1.3255 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0050
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.005.
# Epoch 97/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0333 - sparse_categorical_accuracy: 0.5318 - val_loss: 1.3008 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.005.
# Epoch 98/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0124 - sparse_categorical_accuracy: 0.5504 - val_loss: 1.3524 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0050
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.005.
# Epoch 99/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0297 - sparse_categorical_accuracy: 0.5433 - val_loss: 1.3654 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.005.
# Epoch 100/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0238 - sparse_categorical_accuracy: 0.5404 - val_loss: 1.3178 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0050
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.005.
# Epoch 101/500
# 22/22 [==============================] - 1s 38ms/step - loss: 1.0147 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.2852 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0050
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.002.
# Epoch 102/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9777 - sparse_categorical_accuracy: 0.5558 - val_loss: 1.2889 - val_sparse_categorical_accuracy: 0.5172 - lr: 0.0020
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.002.
# Epoch 103/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9520 - sparse_categorical_accuracy: 0.5730 - val_loss: 1.2995 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.002.
# Epoch 104/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9402 - sparse_categorical_accuracy: 0.5862 - val_loss: 1.3449 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.002.
# Epoch 105/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9255 - sparse_categorical_accuracy: 0.5880 - val_loss: 1.2861 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.002.
# Epoch 106/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9236 - sparse_categorical_accuracy: 0.5840 - val_loss: 1.3430 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.002.
# Epoch 107/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9156 - sparse_categorical_accuracy: 0.5840 - val_loss: 1.3377 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.002.
# Epoch 108/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9102 - sparse_categorical_accuracy: 0.5966 - val_loss: 1.3915 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.002.
# Epoch 109/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8979 - sparse_categorical_accuracy: 0.5919 - val_loss: 1.3293 - val_sparse_categorical_accuracy: 0.4483 - lr: 0.0020
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.002.
# Epoch 110/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8991 - sparse_categorical_accuracy: 0.5984 - val_loss: 1.4123 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.002.
# Epoch 111/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8963 - sparse_categorical_accuracy: 0.5951 - val_loss: 1.4725 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.002.
# Epoch 112/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.8817 - sparse_categorical_accuracy: 0.5976 - val_loss: 1.4298 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.002.
# Epoch 113/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8756 - sparse_categorical_accuracy: 0.6012 - val_loss: 1.3893 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.002.
# Epoch 114/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8821 - sparse_categorical_accuracy: 0.6077 - val_loss: 1.3956 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.002.
# Epoch 115/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8587 - sparse_categorical_accuracy: 0.6220 - val_loss: 1.4735 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.002.
# Epoch 116/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8450 - sparse_categorical_accuracy: 0.6187 - val_loss: 1.5181 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.002.
# Epoch 117/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8561 - sparse_categorical_accuracy: 0.6223 - val_loss: 1.4735 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.002.
# Epoch 118/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8320 - sparse_categorical_accuracy: 0.6363 - val_loss: 1.4812 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.002.
# Epoch 119/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.8411 - sparse_categorical_accuracy: 0.6209 - val_loss: 1.6906 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.002.
# Epoch 120/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8403 - sparse_categorical_accuracy: 0.6170 - val_loss: 1.6440 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.002.
# Epoch 121/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8368 - sparse_categorical_accuracy: 0.6198 - val_loss: 1.5669 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.002.
# Epoch 122/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8218 - sparse_categorical_accuracy: 0.6270 - val_loss: 1.5968 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.002.
# Epoch 123/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8168 - sparse_categorical_accuracy: 0.6406 - val_loss: 1.6308 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.002.
# Epoch 124/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8122 - sparse_categorical_accuracy: 0.6384 - val_loss: 1.6056 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.002.
# Epoch 125/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8008 - sparse_categorical_accuracy: 0.6338 - val_loss: 1.7425 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.002.
# Epoch 126/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8218 - sparse_categorical_accuracy: 0.6384 - val_loss: 1.8278 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.002.
# Epoch 127/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7806 - sparse_categorical_accuracy: 0.6552 - val_loss: 1.7107 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.002.
# Epoch 128/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7918 - sparse_categorical_accuracy: 0.6338 - val_loss: 1.5125 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.002.
# Epoch 129/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.7837 - sparse_categorical_accuracy: 0.6509 - val_loss: 1.7586 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.002.
# Epoch 130/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7855 - sparse_categorical_accuracy: 0.6434 - val_loss: 1.6233 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.002.
# Epoch 131/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7580 - sparse_categorical_accuracy: 0.6556 - val_loss: 1.5869 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.002.
# Epoch 132/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7805 - sparse_categorical_accuracy: 0.6431 - val_loss: 1.5805 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.002.
# Epoch 133/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7624 - sparse_categorical_accuracy: 0.6538 - val_loss: 1.6875 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.002.
# Epoch 134/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7743 - sparse_categorical_accuracy: 0.6574 - val_loss: 1.7614 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.002.
# Epoch 135/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7517 - sparse_categorical_accuracy: 0.6674 - val_loss: 1.6550 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.002.
# Epoch 136/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7386 - sparse_categorical_accuracy: 0.6631 - val_loss: 1.8727 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.002.
# Epoch 137/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.7275 - sparse_categorical_accuracy: 0.6688 - val_loss: 1.7581 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.002.
# Epoch 138/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7101 - sparse_categorical_accuracy: 0.6888 - val_loss: 1.8168 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.002.
# Epoch 139/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7164 - sparse_categorical_accuracy: 0.6763 - val_loss: 2.0158 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.002.
# Epoch 140/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7193 - sparse_categorical_accuracy: 0.6906 - val_loss: 1.8321 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0020
#
# Epoch 141: LearningRateScheduler setting learning rate to 0.002.
# Epoch 141/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7092 - sparse_categorical_accuracy: 0.6845 - val_loss: 2.1031 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.002.
# Epoch 142/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6981 - sparse_categorical_accuracy: 0.6849 - val_loss: 1.8852 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.002.
# Epoch 143/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6836 - sparse_categorical_accuracy: 0.6942 - val_loss: 1.9741 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.002.
# Epoch 144/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6895 - sparse_categorical_accuracy: 0.6871 - val_loss: 1.9967 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.002.
# Epoch 145/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6739 - sparse_categorical_accuracy: 0.7053 - val_loss: 2.1250 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.002.
# Epoch 146/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.6837 - sparse_categorical_accuracy: 0.6928 - val_loss: 2.0893 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.002.
# Epoch 147/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6757 - sparse_categorical_accuracy: 0.6978 - val_loss: 2.0776 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0020
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.002.
# Epoch 148/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6745 - sparse_categorical_accuracy: 0.6956 - val_loss: 2.0494 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0020
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.002.
# Epoch 149/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6628 - sparse_categorical_accuracy: 0.7071 - val_loss: 1.9978 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.002.
# Epoch 150/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6535 - sparse_categorical_accuracy: 0.7132 - val_loss: 2.1967 - val_sparse_categorical_accuracy: 0.4138 - lr: 0.0020
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.002.
# Epoch 151/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6468 - sparse_categorical_accuracy: 0.7099 - val_loss: 1.9999 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0020
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.001.
# Epoch 152/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6026 - sparse_categorical_accuracy: 0.7393 - val_loss: 1.9686 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.001.
# Epoch 153/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5857 - sparse_categorical_accuracy: 0.7310 - val_loss: 2.0788 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.001.
# Epoch 154/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.5676 - sparse_categorical_accuracy: 0.7543 - val_loss: 2.0434 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.001.
# Epoch 155/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5711 - sparse_categorical_accuracy: 0.7539 - val_loss: 2.0183 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.001.
# Epoch 156/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5692 - sparse_categorical_accuracy: 0.7450 - val_loss: 1.9876 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.001.
# Epoch 157/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5612 - sparse_categorical_accuracy: 0.7597 - val_loss: 2.2094 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.001.
# Epoch 158/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5602 - sparse_categorical_accuracy: 0.7529 - val_loss: 2.1367 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.001.
# Epoch 159/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5434 - sparse_categorical_accuracy: 0.7636 - val_loss: 2.3689 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.001.
# Epoch 160/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5413 - sparse_categorical_accuracy: 0.7654 - val_loss: 2.1622 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.001.
# Epoch 161/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5354 - sparse_categorical_accuracy: 0.7707 - val_loss: 2.2289 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.001.
# Epoch 162/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5391 - sparse_categorical_accuracy: 0.7679 - val_loss: 2.2469 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.001.
# Epoch 163/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5381 - sparse_categorical_accuracy: 0.7754 - val_loss: 2.2435 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.001.
# Epoch 164/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5301 - sparse_categorical_accuracy: 0.7686 - val_loss: 2.4095 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.001.
# Epoch 165/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.5365 - sparse_categorical_accuracy: 0.7661 - val_loss: 2.2469 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.001.
# Epoch 166/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5224 - sparse_categorical_accuracy: 0.7718 - val_loss: 2.4055 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.001.
# Epoch 167/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5051 - sparse_categorical_accuracy: 0.7868 - val_loss: 2.3299 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.001.
# Epoch 168/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5102 - sparse_categorical_accuracy: 0.7833 - val_loss: 2.3259 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.001.
# Epoch 169/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.5151 - sparse_categorical_accuracy: 0.7779 - val_loss: 2.2629 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.001.
# Epoch 170/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4886 - sparse_categorical_accuracy: 0.7890 - val_loss: 2.2924 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.001.
# Epoch 171/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4924 - sparse_categorical_accuracy: 0.7854 - val_loss: 2.3848 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.001.
# Epoch 172/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4986 - sparse_categorical_accuracy: 0.7786 - val_loss: 2.3706 - val_sparse_categorical_accuracy: 0.2759 - lr: 0.0010
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.001.
# Epoch 173/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4821 - sparse_categorical_accuracy: 0.7911 - val_loss: 2.4170 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.001.
# Epoch 174/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4845 - sparse_categorical_accuracy: 0.7969 - val_loss: 2.3961 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.001.
# Epoch 175/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4640 - sparse_categorical_accuracy: 0.8015 - val_loss: 2.5516 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.001.
# Epoch 176/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4720 - sparse_categorical_accuracy: 0.7986 - val_loss: 2.2844 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.001.
# Epoch 177/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4690 - sparse_categorical_accuracy: 0.7983 - val_loss: 2.5958 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.001.
# Epoch 178/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4841 - sparse_categorical_accuracy: 0.7843 - val_loss: 2.4615 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.001.
# Epoch 179/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4435 - sparse_categorical_accuracy: 0.8151 - val_loss: 2.6141 - val_sparse_categorical_accuracy: 0.3793 - lr: 0.0010
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.001.
# Epoch 180/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4662 - sparse_categorical_accuracy: 0.8047 - val_loss: 2.4629 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.001.
# Epoch 181/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4522 - sparse_categorical_accuracy: 0.8137 - val_loss: 2.6220 - val_sparse_categorical_accuracy: 0.3103 - lr: 0.0010
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.001.
# Epoch 182/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4472 - sparse_categorical_accuracy: 0.8126 - val_loss: 2.4654 - val_sparse_categorical_accuracy: 0.3448 - lr: 0.0010
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.001.
# Epoch 183/500
# ...
#
# Epoch 441: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 441/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9703 - val_loss: 4.7686 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 442: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 442/500
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9703 - val_loss: 4.8062 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 443: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 443/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0985 - sparse_categorical_accuracy: 0.9671 - val_loss: 4.8433 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 444: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 444/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0969 - sparse_categorical_accuracy: 0.9653 - val_loss: 4.8064 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 445: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 445/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0924 - sparse_categorical_accuracy: 0.9707 - val_loss: 4.8797 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 446: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 446/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0967 - sparse_categorical_accuracy: 0.9664 - val_loss: 4.8765 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 447: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 447/500
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9707 - val_loss: 4.8911 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 448: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 448/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0997 - sparse_categorical_accuracy: 0.9671 - val_loss: 4.9341 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 449: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 449/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0875 - sparse_categorical_accuracy: 0.9728 - val_loss: 4.9069 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 450: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 450/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0932 - sparse_categorical_accuracy: 0.9692 - val_loss: 4.9312 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 451: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 451/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0894 - sparse_categorical_accuracy: 0.9732 - val_loss: 4.9092 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 452: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 452/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9685 - val_loss: 4.9714 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 453: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 453/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0875 - sparse_categorical_accuracy: 0.9725 - val_loss: 4.9869 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 454: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 454/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0845 - sparse_categorical_accuracy: 0.9739 - val_loss: 4.9809 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 455: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 455/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9700 - val_loss: 5.0041 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 456: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 456/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0963 - sparse_categorical_accuracy: 0.9707 - val_loss: 4.9958 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 457: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 457/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0986 - sparse_categorical_accuracy: 0.9671 - val_loss: 4.9605 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 458: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 458/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0866 - sparse_categorical_accuracy: 0.9725 - val_loss: 4.9358 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 459: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 459/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0894 - sparse_categorical_accuracy: 0.9707 - val_loss: 4.9525 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 460: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 460/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9717 - val_loss: 4.9645 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 461: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 461/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9707 - val_loss: 4.9241 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 462: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 462/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0882 - sparse_categorical_accuracy: 0.9721 - val_loss: 4.8955 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 463: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 463/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9728 - val_loss: 4.8932 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 464: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 464/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0899 - sparse_categorical_accuracy: 0.9725 - val_loss: 4.8994 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 465: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 465/500
# 22/22 [==============================] - 1s 40ms/step - loss: 0.1055 - sparse_categorical_accuracy: 0.9628 - val_loss: 4.9215 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 466: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 466/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.1006 - sparse_categorical_accuracy: 0.9635 - val_loss: 4.9248 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 467: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 467/500
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9721 - val_loss: 4.9738 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 468: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 468/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0918 - sparse_categorical_accuracy: 0.9700 - val_loss: 4.9430 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 469: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 469/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0958 - sparse_categorical_accuracy: 0.9642 - val_loss: 4.9133 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 470: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 470/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0966 - sparse_categorical_accuracy: 0.9653 - val_loss: 4.9375 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 471: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 471/500
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0871 - sparse_categorical_accuracy: 0.9717 - val_loss: 4.9042 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 472: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 472/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0889 - sparse_categorical_accuracy: 0.9703 - val_loss: 4.9251 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 473: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 473/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0950 - sparse_categorical_accuracy: 0.9678 - val_loss: 4.9251 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 474: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 474/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0947 - sparse_categorical_accuracy: 0.9692 - val_loss: 4.8978 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 475: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 475/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0828 - sparse_categorical_accuracy: 0.9746 - val_loss: 4.9138 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 476: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 476/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0944 - sparse_categorical_accuracy: 0.9696 - val_loss: 4.9572 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 477: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 477/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9728 - val_loss: 5.0201 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 478: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 478/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9707 - val_loss: 5.0777 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 479: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 479/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0798 - sparse_categorical_accuracy: 0.9771 - val_loss: 5.0505 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 480: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 480/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0832 - sparse_categorical_accuracy: 0.9739 - val_loss: 5.0412 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 481: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 481/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0774 - sparse_categorical_accuracy: 0.9789 - val_loss: 5.0454 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 482: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 482/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0955 - sparse_categorical_accuracy: 0.9692 - val_loss: 5.0586 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 483: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 483/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0773 - sparse_categorical_accuracy: 0.9732 - val_loss: 5.0648 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 484: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 484/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0858 - sparse_categorical_accuracy: 0.9725 - val_loss: 5.1266 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 485: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 485/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0891 - sparse_categorical_accuracy: 0.9710 - val_loss: 5.0960 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 486: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 486/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0843 - sparse_categorical_accuracy: 0.9725 - val_loss: 5.0601 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 487: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 487/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0804 - sparse_categorical_accuracy: 0.9742 - val_loss: 5.0262 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 488: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 488/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9707 - val_loss: 5.0279 - val_sparse_categorical_accuracy: 0.4138 - lr: 1.0000e-04
#
# Epoch 489: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 489/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0899 - sparse_categorical_accuracy: 0.9689 - val_loss: 5.0020 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 490: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 490/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9742 - val_loss: 5.0625 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 491: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 491/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0904 - sparse_categorical_accuracy: 0.9700 - val_loss: 5.0616 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 492: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 492/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0792 - sparse_categorical_accuracy: 0.9739 - val_loss: 5.0527 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 493: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 493/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9692 - val_loss: 5.0401 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 494: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 494/500
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0823 - sparse_categorical_accuracy: 0.9742 - val_loss: 5.0289 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 495: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 495/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0949 - sparse_categorical_accuracy: 0.9653 - val_loss: 5.0136 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 496: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 496/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0862 - sparse_categorical_accuracy: 0.9692 - val_loss: 5.0099 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 497: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 497/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0785 - sparse_categorical_accuracy: 0.9735 - val_loss: 4.9982 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 498: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 498/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9682 - val_loss: 4.9993 - val_sparse_categorical_accuracy: 0.3448 - lr: 1.0000e-04
#
# Epoch 499: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 499/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0782 - sparse_categorical_accuracy: 0.9785 - val_loss: 4.9583 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04
#
# Epoch 500: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 500/500
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0833 - sparse_categorical_accuracy: 0.9714 - val_loss: 4.9036 - val_sparse_categorical_accuracy: 0.3793 - lr: 1.0000e-04

# %%
train_acc = history.history['sparse_categorical_accuracy']
train_loss = history.history['loss']

val_acc = history.history['val_sparse_categorical_accuracy']
val_loss = history.history['val_loss']

plt.figure()
plt.plot(range(epoch), train_loss, label='train_loss')
plt.plot(range(epoch), val_loss, label='val_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

plt.figure()
plt.plot(range(epoch), train_acc, label='train_acc')
plt.plot(range(epoch), val_acc, label='val_acc')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('msle')
plt.show()

# %%
model.evaluate(test_ds)

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)

df_time = date[-len(y_test):]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, y_test, 'b-', label='actual')
axes.plot(df_time, y_pred, 'r--', label='predict')
print(y_pred)
axes.set_xticks(df_time[::1])
axes.set_xticklabels(df_time[::1],rotation=45)

plt.legend()
plt.grid()
plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step - loss: 4.9036 - sparse_categorical_accuracy: 0.3793
# 1/1 [==============================] - 0s 116ms/step
# [4 4 4 5 5 5 5 4 4 5 5 5 5 3 4 4 4 3 3 5 5 5 5 4 1 1 1 1 1]
# 2023-07-21 12:34:41.733818: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
price_actual = list()
price_pred = list()
price_actual.append(1.0)
price_pred.append(1.0)
    

for idx in range(1, len(y_test)):
    price_actual.append(price_actual[idx-1] * change_test[idx])
    price_pred.append(price_pred[idx-1] * label2change(y_pred[idx]))
print(price_actual)
print(price_pred)
# Out:
# [1.0, 1.0021977424621582, 0.9978021550964513, 1.0703295490642146, 1.0659339624585153, 1.0439559413040178, 1.0417581053935308, 1.054945052045385, 1.0417581257114925, 1.024175695415759, 0.980219668513828, 1.0197800233944425, 1.0835162748565952, 1.0593405525378703, 1.0923075486453682, 1.0923075486453682, 1.0791207269749712, 1.109890033315542, 1.1230768945862628, 1.1010988900646868, 1.0901098322880776, 1.1670328967470367, 1.2065932513953992, 1.1450548391680666, 1.2175822808848387, 1.3054944071347725, 1.2043954890251036, 1.2879119938852652, 1.417582189377483]
# [1.0, 0.99, 0.9801, 1.0781100000000001, 1.1859210000000002, 1.3045131000000003, 1.4349644100000005, 1.4206147659000006, 1.4064086182410005, 1.5470494800651007, 1.7017544280716108, 1.871929870878772, 2.059122857966649, 1.9973491722276497, 1.9773756805053733, 1.9576019237003195, 1.9380259044633164, 1.8798851273294168, 1.8234885735095343, 2.005837430860488, 2.206421173946537, 2.4270632913411907, 2.66976962047531, 2.643071924270557, 2.458056889571618, 2.285992907301605, 2.125973403790493, 1.9771552655251587, 1.8387543969383977]

# %%
df_time = date[-len(y_test):]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, price_actual, 'b-', label='actual')
axes.plot(df_time, price_pred, 'r--', label='predict')

axes.set_xticks(df_time[::1])
axes.set_xticklabels(df_time[::1],rotation=45)

plt.legend()
plt.grid()
plt.show()

# %%
actual_profit_rate = 1
for idx in range(0, len(y_pred)):
    if y_pred[idx] >= 1:
        actual_profit_rate *= change_test[idx]
print(actual_profit_rate)
# Out:
# 1.4052285045252226

# %%
predict_train = model.predict(x_train)
predict_train = np.argmax(predict_train, axis=1)

df_time = date[mem_his_days + pre_days - 1 :mem_his_days + pre_days - 1 + len(predict_train)]

fig = plt.figure(figsize=(30, 5))
axes = fig.add_subplot(111)
axes.plot(df_time, y_train, 'b-', label='actual')
print(predict_train.shape)
axes.plot(df_time, predict_train, 'r--', label='predict')

axes.set_xticks(df_time[::100])
axes.set_xticklabels(df_time[::100],rotation=45)

plt.legend()
plt.grid()
plt.show()
# Out:
# 88/88 [==============================] - 1s 8ms/step
# (2796,)

# %%
predict_x = np.array(predict_x).reshape(-1,17,17,1)
predict = model.predict(predict_x)
predict = np.argmax(predict, axis=1)

def up_or_down(pred):
    if pred >= 3:
        return '↗'
    return '↘'
print('Current code is ' + stock_code + ', current date is ' + newest_data)
print('T+1 ' + up_or_down(predict[0]))
print('T+2 ' + up_or_down(predict[1]))
# Out:
# 1/1 [==============================] - 0s 139ms/step
# Current code is 002316, current date is 2023-07-20
# T+1 ↘
# T+2 ↗
